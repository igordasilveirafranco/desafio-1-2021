# %% [markdown]
# # Desafio 1 - Maratona Behind the Code 2021
#
# ### Notebook guia
#
# Esse Jupyter Notebook te dará instruções para criar uma solução introdutória para o desafio 1 da Maratona. Sinta-se livre para editar e melhorar sua solução!

# %% [markdown]
# **Atenção: se estiver utilizando o Watson Studio, lembre-se de deixar o Notebook como editável, clicando no botão de editar acima.**
#
# ![](https://s3.br-sao.cloud-object-storage.appdomain.cloud/maratona-static/edit-notebook.png)

# %% [markdown]
# ## Exploração do dataset
#
# O primeiro passo para o desenvolvimento de um bom modelo de Machine Learning é explorar bem os dados que temos para trabalhar. Devemos entender o melhor possível a relevância de cada dado para o valor que queremos predizer. Afinal, a predição do modelo é inteiramente baseada nos dados com que treinou.
#
# Existem muitas bibliotecas em Python que podem ser utilizadas para tratamento e visualização de dados. Nesses exemplos, vamos usar Pandas, Seaborn e Matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Primeiramente, vamos carregar o dataset do desafio neste Notebook. Vamos começar com o principal, `LOANS.csv`. Para isso, podemos usar o ícone de assets, disponível no canto superior direito da tela, e inserir o dataset como um DataFrame Pandas, como na imagem abaixo.
#
# <img width="300px" src="https://s3.br-sao.cloud-object-storage.appdomain.cloud/maratona-static/load-loans.png" />
#
# Repita para todos os datasets que for utilizar.

# %%
# Carregue aqui o dataset
demogra = pd.read_csv("..\data\Demographics.csv")
accounts = pd.read_csv("..\data\Accounts.csv")
loans = pd.read_csv("..\data\loans.csv")

# %% [markdown]
# Renomeie o nome da variável criada com o dataset para `loans`, para ficar de acordo com os códigos abaixo.

# %% [markdown]
# Podemos usar os métodos `.info()` e `.describe()` para obter informações básicas sobre quantidade presente dos dados, tipos e valores deles.

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   3999 non-null   int64
#  1   PAYMENT_TERM         3975 non-null   float64
#  2   INSTALLMENT_PLANS    3978 non-null   object
#  3   INSTALLMENT_PERCENT  3974 non-null   float64
#  4   LOAN_PURPOSE         3979 non-null   object
#  5   LOAN_AMOUNT          3981 non-null   float64
#  6   OTHERS_ON_LOAN       3977 non-null   object
#  7   ALLOW                3999 non-null   int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 250.1+ KB

# %%
loans.describe()
# Out:
#                  ID  PAYMENT_TERM  INSTALLMENT_PERCENT   LOAN_AMOUNT  \
# count  3.999000e+03   3975.000000          3974.000000   3981.000000
# mean   6.603562e+05    653.796981             2.981379   3479.168802
# std    3.728332e+05    338.723239             1.121448   2489.961917
# min    9.800000e+01    120.000000             1.000000    250.000000
# 25%    3.418460e+05    390.000000             2.000000   1330.000000
# 50%    6.670610e+05    651.000000             3.000000   3237.000000
# 75%    9.778745e+05    899.000000             4.000000   5334.000000
# max    1.320082e+06   1984.000000             6.000000  11676.000000
#
#              ALLOW
# count  3999.000000
# mean      0.664166
# std       0.472340
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# A variável destino para este desafio é a `ALLOW`, significando se um empréstimo deverá ser permitido ou não, baseado nas informações dadas. Vamos dar uma olhada em como está a distribuição dessa variável

# %%
risk_plot = sns.countplot(data=loans, x='ALLOW', order=loans['ALLOW'].value_counts().index)
plt.show()

# %% [markdown]
# Sinta-se livre para ver a distribuição de outras colunas do conjunto de dados, utilizar os outros conjuntos de dados, explorar as correlações entre variáveis e outros.

# %%
# Adicione suas explorações

# %%
lo_de = loans.merge(demogra)

# %%
# lo_de_ac = lo_de.merge(accounts, on='ID', how='left')

# %%
# lo_de_ac.count()

# %% [markdown]
# ## Tratamento dos dados

# %% [markdown]
# Uma vez que exploramos os dados, entendemos a importância de cada coluna e podemos fazer alterações nelas para para obter um melhor resultado. Aqui, vamos fazer apenas um tratamento simples, de remover do dataset as linhas que tiverem faltando algum valor. Não necessariamente essa técnica é a melhor para se utilizar no desafio, é apenas um exemplo de como tratar o dataset.
#
# Para tratamentos mais avançados, como modificação de colunas ou criação de novas colunas, veja mais abaixo no Notebook, em que explicamos como utilizar as `Pipelines`, da biblioteca `sklearn`, para realizar transformações nos dados.

# %%
clean_df = lo_de.dropna()
clean_df.count()
# Out:
# ID                            3615
# PAYMENT_TERM                  3615
# INSTALLMENT_PLANS             3615
# INSTALLMENT_PERCENT           3615
# LOAN_PURPOSE                  3615
# LOAN_AMOUNT                   3615
# OTHERS_ON_LOAN                3615
# ALLOW                         3615
# SEX                           3615
# AGE                           3615
# JOB_TYPE                      3615
# DEPENDENTS                    3615
# TELEPHONE                     3615
# FOREIGN_WORKER                3615
# EMPLOYMENT_DURATION           3615
# PROPERTY                      3615
# HOUSING                       3615
# CURRENT_RESIDENCE_DURATION    3615
# dtype: int64

# %% [markdown]
# Podemos observar que agora temos um dataset "limpo", mas perdemos alguns dados por remover as linhas em que pelo menos uma coluna estava faltando.

# %% [markdown]
# Observando a execução do método `.info()` acima, podemos ver que existem três colunas do tipo `object`. O modelo do `scikit-learn` que vamos usar não é capaz de processar uma variável desse tipo. Portanto, para dar seguimento ao experimento, vamos remover essa coluna. Recomendamos que você use alguma técnica para tratamento de variáveis categóricas, como o _one-hot encoding_, em vez de remover a coluna.
#
# Vamos também remover a coluna `ID`, pois sabemos que ela não é uma informação útil para a predição (é apenas um número identificando um cliente).

# %%
object_columns = ['INSTALLMENT_PLANS','SEX']
clean_df = clean_df.drop(object_columns, axis=1)
clean_df = clean_df.drop('ID', axis=1)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3615 entries, 0 to 3935
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PAYMENT_TERM                3615 non-null   float64
#  1   INSTALLMENT_PERCENT         3615 non-null   float64
#  2   LOAN_PURPOSE                3615 non-null   object
#  3   LOAN_AMOUNT                 3615 non-null   float64
#  4   OTHERS_ON_LOAN              3615 non-null   object
#  5   ALLOW                       3615 non-null   int64
#  6   AGE                         3615 non-null   float64
#  7   JOB_TYPE                    3615 non-null   float64
#  8   DEPENDENTS                  3615 non-null   float64
#  9   TELEPHONE                   3615 non-null   float64
#  10  FOREIGN_WORKER              3615 non-null   float64
#  11  EMPLOYMENT_DURATION         3615 non-null   float64
#  12  PROPERTY                    3615 non-null   object
#  13  HOUSING                     3615 non-null   object
#  14  CURRENT_RESIDENCE_DURATION  3615 non-null   float64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 451.9+ KB

# %% [markdown]
# ### Usando One-Hot Encoding

# %%
# from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
temp_n = pd.get_dummies(clean_df, columns=['LOAN_PURPOSE','OTHERS_ON_LOAN','PROPERTY','HOUSING'])

# %%
temp_n.columns
# Out:
# Index(['PAYMENT_TERM', 'INSTALLMENT_PERCENT', 'LOAN_AMOUNT', 'ALLOW', 'AGE',
#        'JOB_TYPE', 'DEPENDENTS', 'TELEPHONE', 'FOREIGN_WORKER',
#        'EMPLOYMENT_DURATION', 'CURRENT_RESIDENCE_DURATION',
#        'LOAN_PURPOSE_APPLIANCES', 'LOAN_PURPOSE_BUSINESS',
#        'LOAN_PURPOSE_CAR_NEW', 'LOAN_PURPOSE_CAR_USED',
#        'LOAN_PURPOSE_EDUCATION', 'LOAN_PURPOSE_FURNITURE',
#        'LOAN_PURPOSE_OTHER', 'LOAN_PURPOSE_RADIO_TV', 'LOAN_PURPOSE_REPAIRS',
#        'LOAN_PURPOSE_RETRAINING', 'LOAN_PURPOSE_VACATION',
#        'OTHERS_ON_LOAN_CO-APPLICANT', 'OTHERS_ON_LOAN_GUARANTOR',
#        'OTHERS_ON_LOAN_NONE', 'PROPERTY_CAR_OTHER', 'PROPERTY_REAL_ESTATE',
#        'PROPERTY_SAVINGS_INSURANCE', 'PROPERTY_UNKNOWN', 'HOUSING_FREE',
#        'HOUSING_OWN', 'HOUSING_RENT'],
#       dtype='object')

# %% [markdown]
# ## Criação do modelo
#
# Com os dados prontos, podemos selecionar um modelo de Machine Learning para treinar com nossos dados. Nesse exemplo, vamos utilizar um modelo de classificação básico, o de Árvore de Decisão.
#
# Para conseguir avaliar o desempenho do nosso modelo, vamos dividir os dados que temos entre dados de treino e de teste, e assim, após o treinamento, verificar como ele está se saindo com as predições.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Abaixo, separamos os dados que queremos predizer dos dados que utilizamos como informações para a predição.

# %%
features = ['PAYMENT_TERM', 'INSTALLMENT_PERCENT', 'LOAN_AMOUNT', 'AGE',
       'JOB_TYPE', 'DEPENDENTS', 'TELEPHONE', 'FOREIGN_WORKER',
       'EMPLOYMENT_DURATION', 'CURRENT_RESIDENCE_DURATION',
       'LOAN_PURPOSE_APPLIANCES', 'LOAN_PURPOSE_BUSINESS',
       'LOAN_PURPOSE_CAR_NEW', 'LOAN_PURPOSE_CAR_USED',
       'LOAN_PURPOSE_EDUCATION', 'LOAN_PURPOSE_FURNITURE',
       'LOAN_PURPOSE_OTHER', 'LOAN_PURPOSE_RADIO_TV', 'LOAN_PURPOSE_REPAIRS',
       'LOAN_PURPOSE_RETRAINING', 'LOAN_PURPOSE_VACATION',
       'OTHERS_ON_LOAN_CO-APPLICANT', 'OTHERS_ON_LOAN_GUARANTOR',
       'OTHERS_ON_LOAN_NONE', 'PROPERTY_CAR_OTHER', 'PROPERTY_REAL_ESTATE',
       'PROPERTY_SAVINGS_INSURANCE', 'PROPERTY_UNKNOWN', 'HOUSING_FREE',
       'HOUSING_OWN', 'HOUSING_RENT']
target = ['ALLOW']

# X = clean_df[features]
# y = clean_df[target]
X = temp_n[features]
y = temp_n[target]

# %%
test_pct = 0.3 # Separaremos 30% dos dados para testes
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_pct, random_state=0)

# quando coloco max_depth para 4, sobe de 68% para 76%
model = DecisionTreeClassifier(random_state=0, max_depth=4)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Acurácia do modelo (número de predições assertivas sobre número total de testes): {acc}")
# Out:
# Acurácia do modelo (número de predições assertivas sobre número total de testes): 0.7557603686635944

# %%
plt.figure(figsize=(15,7.5))
plot_tree(model, filled=True, rounded=True, class_names=["No HD","Yes HD"], feature_names=X.columns)
# Out:
# [Text(472.20491726720246, 397.99285714285713, 'PAYMENT_TERM <= 777.5\ngini = 0.446\nsamples = 2530\nvalue = [851, 1679]\nclass = Yes HD'),
#  Text(321.12547219547025, 378.5785714285714, 'AGE <= 43.5\ngini = 0.307\nsamples = 1583\nvalue = [300, 1283]\nclass = Yes HD'),
#  Text(248.628567929729, 359.1642857142857, 'PROPERTY_REAL_ESTATE <= 0.5\ngini = 0.252\nsamples = 1392\nvalue = [206, 1186]\nclass = Yes HD'),
#  Text(162.36818793172156, 339.75, 'EMPLOYMENT_DURATION <= 5.5\ngini = 0.335\nsamples = 906\nvalue = [193, 713]\nclass = Yes HD'),
#  Text(79.57365003985122, 320.3357142857143, 'PAYMENT_TERM <= 381.0\ngini = 0.279\nsamples = 687\nvalue = [115, 572]\nclass = Yes HD'),
#  Text(15.1211477151966, 300.9214285714286, 'AGE <= 42.5\ngini = 0.153\nsamples = 239\nvalue = [20, 219]\nclass = Yes HD'),
#  Text(13.342189160467587, 281.50714285714287, 'LOAN_AMOUNT <= 968.5\ngini = 0.147\nsamples = 238\nvalue = [19, 219]\nclass = Yes HD'),
#  Text(3.5579171094580233, 262.09285714285716, 'CURRENT_RESIDENCE_DURATION <= 2.5\ngini = 0.057\nsamples = 102\nvalue = [3, 99]\nclass = Yes HD'),
#  Text(1.7789585547290117, 242.67857142857142, 'gini = 0.0\nsamples = 78\nvalue = [0, 78]\nclass = Yes HD'),
#  Text(5.336875664187035, 242.67857142857142, 'EMPLOYMENT_DURATION <= 0.5\ngini = 0.219\nsamples = 24\nvalue = [3, 21]\nclass = Yes HD'),
#  Text(3.5579171094580233, 223.2642857142857, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Yes HD'),
#  Text(7.115834218916047, 223.2642857142857, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]\nclass = Yes HD'),
#  Text(5.336875664187035, 203.85, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(8.894792773645058, 203.85, 'LOAN_AMOUNT <= 345.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]\nclass = Yes HD'),
#  Text(7.115834218916047, 184.43571428571428, 'PAYMENT_TERM <= 182.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Yes HD'),
#  Text(5.336875664187035, 165.02142857142854, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(8.894792773645058, 165.02142857142854, 'LOAN_PURPOSE_CAR_USED <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(7.115834218916047, 145.60714285714283, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(10.67375132837407, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(10.67375132837407, 184.43571428571428, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(23.126461211477153, 262.09285714285716, 'LOAN_AMOUNT <= 992.5\ngini = 0.208\nsamples = 136\nvalue = [16, 120]\nclass = Yes HD'),
#  Text(19.56854410201913, 242.67857142857142, 'LOAN_PURPOSE_EDUCATION <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(17.789585547290116, 223.2642857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(21.34750265674814, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(26.684378320935174, 242.67857142857142, 'LOAN_PURPOSE_REPAIRS <= 0.5\ngini = 0.178\nsamples = 132\nvalue = [13, 119]\nclass = Yes HD'),
#  Text(24.905419766206162, 223.2642857142857, 'AGE <= 33.5\ngini = 0.166\nsamples = 131\nvalue = [12, 119]\nclass = Yes HD'),
#  Text(17.789585547290116, 203.85, 'LOAN_AMOUNT <= 5916.5\ngini = 0.086\nsamples = 89\nvalue = [4, 85]\nclass = Yes HD'),
#  Text(14.231668437832093, 184.43571428571428, 'LOAN_AMOUNT <= 2304.5\ngini = 0.067\nsamples = 87\nvalue = [3, 84]\nclass = Yes HD'),
#  Text(12.452709883103081, 165.02142857142854, 'gini = 0.0\nsamples = 48\nvalue = [0, 48]\nclass = Yes HD'),
#  Text(16.010626992561104, 165.02142857142854, 'LOAN_AMOUNT <= 2318.0\ngini = 0.142\nsamples = 39\nvalue = [3, 36]\nclass = Yes HD'),
#  Text(14.231668437832093, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(17.789585547290116, 145.60714285714283, 'PAYMENT_TERM <= 335.5\ngini = 0.1\nsamples = 38\nvalue = [2, 36]\nclass = Yes HD'),
#  Text(16.010626992561104, 126.19285714285712, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]\nclass = Yes HD'),
#  Text(19.56854410201913, 126.19285714285712, 'LOAN_PURPOSE_CAR_USED <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Yes HD'),
#  Text(17.789585547290116, 106.77857142857141, 'TELEPHONE <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Yes HD'),
#  Text(16.010626992561104, 87.3642857142857, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Yes HD'),
#  Text(19.56854410201913, 87.3642857142857, 'LOAN_AMOUNT <= 4274.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(17.789585547290116, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(21.34750265674814, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(21.34750265674814, 106.77857142857141, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(21.34750265674814, 184.43571428571428, 'LOAN_AMOUNT <= 6592.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(19.56854410201913, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(23.126461211477153, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(32.02125398512221, 203.85, 'LOAN_AMOUNT <= 2386.0\ngini = 0.308\nsamples = 42\nvalue = [8, 34]\nclass = Yes HD'),
#  Text(28.463336875664186, 184.43571428571428, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.484\nsamples = 17\nvalue = [7, 10]\nclass = Yes HD'),
#  Text(26.684378320935174, 165.02142857142854, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(30.2422954303932, 165.02142857142854, 'LOAN_AMOUNT <= 2364.0\ngini = 0.408\nsamples = 14\nvalue = [4, 10]\nclass = Yes HD'),
#  Text(28.463336875664186, 145.60714285714283, 'LOAN_AMOUNT <= 1192.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Yes HD'),
#  Text(26.684378320935174, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(30.2422954303932, 126.19285714285712, 'JOB_TYPE <= 1.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Yes HD'),
#  Text(28.463336875664186, 106.77857142857141, 'PROPERTY_SAVINGS_INSURANCE <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(26.684378320935174, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(30.2422954303932, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(32.02125398512221, 106.77857142857141, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Yes HD'),
#  Text(32.02125398512221, 145.60714285714283, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(35.57917109458023, 184.43571428571428, 'LOAN_PURPOSE_EDUCATION <= 0.5\ngini = 0.077\nsamples = 25\nvalue = [1, 24]\nclass = Yes HD'),
#  Text(33.80021253985122, 165.02142857142854, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = Yes HD'),
#  Text(37.35812964930925, 165.02142857142854, 'HOUSING_RENT <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(35.57917109458023, 145.60714285714283, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(39.13708820403826, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(28.463336875664186, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(16.90010626992561, 281.50714285714287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(144.02615236450583, 300.9214285714286, 'CURRENT_RESIDENCE_DURATION <= 3.5\ngini = 0.334\nsamples = 448\nvalue = [95, 353]\nclass = Yes HD'),
#  Text(102.15113575982997, 281.50714285714287, 'EMPLOYMENT_DURATION <= 0.5\ngini = 0.298\nsamples = 367\nvalue = [67, 300]\nclass = Yes HD'),
#  Text(56.70430393198725, 262.09285714285716, 'LOAN_PURPOSE_BUSINESS <= 0.5\ngini = 0.207\nsamples = 128\nvalue = [15, 113]\nclass = Yes HD'),
#  Text(54.92534537725823, 242.67857142857142, 'PAYMENT_TERM <= 442.0\ngini = 0.196\nsamples = 127\nvalue = [14, 113]\nclass = Yes HD'),
#  Text(48.031880977683315, 223.2642857142857, 'AGE <= 28.5\ngini = 0.346\nsamples = 27\nvalue = [6, 21]\nclass = Yes HD'),
#  Text(46.252922422954306, 203.85, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Yes HD'),
#  Text(49.810839532412324, 203.85, 'AGE <= 39.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]\nclass = Yes HD'),
#  Text(48.031880977683315, 184.43571428571428, 'LOAN_AMOUNT <= 2075.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = No HD'),
#  Text(44.47396386822529, 165.02142857142854, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Yes HD'),
#  Text(42.69500531349628, 145.60714285714283, 'LOAN_AMOUNT <= 1304.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(40.916046758767266, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(44.47396386822529, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(46.252922422954306, 145.60714285714283, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(51.58979808714134, 165.02142857142854, 'LOAN_AMOUNT <= 4561.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = No HD'),
#  Text(49.810839532412324, 145.60714285714283, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(53.36875664187035, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(51.58979808714134, 184.43571428571428, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(61.818809776833156, 223.2642857142857, 'AGE <= 19.5\ngini = 0.147\nsamples = 100\nvalue = [8, 92]\nclass = Yes HD'),
#  Text(56.92667375132837, 203.85, 'LOAN_AMOUNT <= 1368.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(55.147715196599364, 184.43571428571428, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(58.70563230605738, 184.43571428571428, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(66.71094580233793, 203.85, 'DEPENDENTS <= 1.5\ngini = 0.117\nsamples = 96\nvalue = [6, 90]\nclass = Yes HD'),
#  Text(62.263549415515406, 184.43571428571428, 'LOAN_PURPOSE_CAR_NEW <= 0.5\ngini = 0.087\nsamples = 88\nvalue = [4, 84]\nclass = Yes HD'),
#  Text(58.70563230605738, 165.02142857142854, 'AGE <= 22.5\ngini = 0.03\nsamples = 65\nvalue = [1, 64]\nclass = Yes HD'),
#  Text(56.92667375132837, 145.60714285714283, 'PAYMENT_TERM <= 640.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Yes HD'),
#  Text(55.147715196599364, 126.19285714285712, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(58.70563230605738, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(60.4845908607864, 145.60714285714283, 'gini = 0.0\nsamples = 56\nvalue = [0, 56]\nclass = Yes HD'),
#  Text(65.82146652497343, 165.02142857142854, 'AGE <= 32.5\ngini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = Yes HD'),
#  Text(64.04250797024442, 145.60714285714283, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = Yes HD'),
#  Text(67.60042507970245, 145.60714285714283, 'TELEPHONE <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = Yes HD'),
#  Text(65.82146652497343, 126.19285714285712, 'PAYMENT_TERM <= 518.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = No HD'),
#  Text(64.04250797024442, 106.77857142857141, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(62.263549415515406, 87.3642857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(65.82146652497343, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(67.60042507970245, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(69.37938363443145, 126.19285714285712, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(71.15834218916046, 184.43571428571428, 'JOB_TYPE <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Yes HD'),
#  Text(69.37938363443145, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(72.93730074388948, 165.02142857142854, 'LOAN_AMOUNT <= 1574.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Yes HD'),
#  Text(71.15834218916046, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(74.7162592986185, 145.60714285714283, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(58.48326248671626, 242.67857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(147.59796758767268, 262.09285714285716, 'OTHERS_ON_LOAN_CO-APPLICANT <= 0.5\ngini = 0.34\nsamples = 239\nvalue = [52, 187]\nclass = Yes HD'),
#  Text(126.19487247608926, 242.67857142857142, 'PAYMENT_TERM <= 625.0\ngini = 0.321\nsamples = 224\nvalue = [45, 179]\nclass = Yes HD'),
#  Text(106.51514346439957, 223.2642857142857, 'PAYMENT_TERM <= 518.5\ngini = 0.268\nsamples = 144\nvalue = [23, 121]\nclass = Yes HD'),
#  Text(88.94792773645058, 203.85, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.351\nsamples = 75\nvalue = [17, 58]\nclass = Yes HD'),
#  Text(78.27417640807651, 184.43571428571428, 'AGE <= 21.0\ngini = 0.451\nsamples = 35\nvalue = [12, 23]\nclass = Yes HD'),
#  Text(76.4952178533475, 165.02142857142854, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(80.05313496280553, 165.02142857142854, 'PAYMENT_TERM <= 427.0\ngini = 0.404\nsamples = 32\nvalue = [9, 23]\nclass = Yes HD'),
#  Text(78.27417640807651, 145.60714285714283, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Yes HD'),
#  Text(81.83209351753453, 145.60714285714283, 'AGE <= 26.0\ngini = 0.476\nsamples = 23\nvalue = [9, 14]\nclass = Yes HD'),
#  Text(80.05313496280553, 126.19285714285712, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(83.61105207226355, 126.19285714285712, 'PROPERTY_CAR_OTHER <= 0.5\ngini = 0.444\nsamples = 21\nvalue = [7, 14]\nclass = Yes HD'),
#  Text(80.05313496280553, 106.77857142857141, 'EMPLOYMENT_DURATION <= 1.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]\nclass = Yes HD'),
#  Text(78.27417640807651, 87.3642857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(81.83209351753453, 87.3642857142857, 'PAYMENT_TERM <= 488.0\ngini = 0.463\nsamples = 11\nvalue = [4, 7]\nclass = Yes HD'),
#  Text(80.05313496280553, 67.94999999999999, 'LOAN_PURPOSE_CAR_USED <= 0.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = No HD'),
#  Text(78.27417640807651, 48.53571428571428, 'HOUSING_OWN <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Yes HD'),
#  Text(76.4952178533475, 29.121428571428567, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(80.05313496280553, 29.121428571428567, 'PAYMENT_TERM <= 472.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(78.27417640807651, 9.707142857142856, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(81.83209351753453, 9.707142857142856, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(81.83209351753453, 48.53571428571428, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(83.61105207226355, 67.94999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(87.16896918172156, 106.77857142857141, 'AGE <= 40.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Yes HD'),
#  Text(85.39001062699256, 87.3642857142857, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(88.94792773645058, 87.3642857142857, 'CURRENT_RESIDENCE_DURATION <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(87.16896918172156, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(90.7268862911796, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(99.62167906482465, 184.43571428571428, 'LOAN_AMOUNT <= 6112.5\ngini = 0.219\nsamples = 40\nvalue = [5, 35]\nclass = Yes HD'),
#  Text(97.84272051009565, 165.02142857142854, 'PAYMENT_TERM <= 427.0\ngini = 0.184\nsamples = 39\nvalue = [4, 35]\nclass = Yes HD'),
#  Text(94.28480340063761, 145.60714285714283, 'AGE <= 36.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Yes HD'),
#  Text(92.50584484590861, 126.19285714285712, 'EMPLOYMENT_DURATION <= 3.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Yes HD'),
#  Text(90.7268862911796, 106.77857142857141, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(94.28480340063761, 106.77857142857141, 'AGE <= 30.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(92.50584484590861, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(96.06376195536663, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(96.06376195536663, 126.19285714285712, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(101.40063761955366, 145.60714285714283, 'DEPENDENTS <= 1.5\ngini = 0.067\nsamples = 29\nvalue = [1, 28]\nclass = Yes HD'),
#  Text(99.62167906482465, 126.19285714285712, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]\nclass = Yes HD'),
#  Text(103.17959617428268, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(101.40063761955366, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(124.08235919234856, 203.85, 'PROPERTY_UNKNOWN <= 0.5\ngini = 0.159\nsamples = 69\nvalue = [6, 63]\nclass = Yes HD'),
#  Text(118.30074388947928, 184.43571428571428, 'LOAN_PURPOSE_FURNITURE <= 0.5\ngini = 0.138\nsamples = 67\nvalue = [5, 62]\nclass = Yes HD'),
#  Text(112.07438894792773, 165.02142857142854, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.074\nsamples = 52\nvalue = [2, 50]\nclass = Yes HD'),
#  Text(108.51647183846971, 145.60714285714283, 'EMPLOYMENT_DURATION <= 1.5\ngini = 0.04\nsamples = 49\nvalue = [1, 48]\nclass = Yes HD'),
#  Text(106.7375132837407, 126.19285714285712, 'AGE <= 28.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = Yes HD'),
#  Text(104.95855472901168, 106.77857142857141, 'LOAN_PURPOSE_CAR_NEW <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(103.17959617428268, 87.3642857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(106.7375132837407, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(108.51647183846971, 106.77857142857141, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(110.29543039319873, 126.19285714285712, 'gini = 0.0\nsamples = 39\nvalue = [0, 39]\nclass = Yes HD'),
#  Text(115.63230605738576, 145.60714285714283, 'AGE <= 31.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(113.85334750265675, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(117.41126461211476, 126.19285714285712, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(124.52709883103081, 165.02142857142854, 'DEPENDENTS <= 1.5\ngini = 0.32\nsamples = 15\nvalue = [3, 12]\nclass = Yes HD'),
#  Text(122.74814027630181, 145.60714285714283, 'EMPLOYMENT_DURATION <= 1.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = Yes HD'),
#  Text(120.9691817215728, 126.19285714285712, 'HOUSING_OWN <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(119.19022316684378, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(122.74814027630181, 106.77857142857141, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(124.52709883103081, 126.19285714285712, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Yes HD'),
#  Text(126.30605738575983, 145.60714285714283, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(129.86397449521786, 184.43571428571428, 'JOB_TYPE <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(128.08501594048883, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(131.64293304994686, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(145.87460148777896, 223.2642857142857, 'CURRENT_RESIDENCE_DURATION <= 1.5\ngini = 0.399\nsamples = 80\nvalue = [22, 58]\nclass = Yes HD'),
#  Text(138.7587672688629, 203.85, 'HOUSING_FREE <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]\nclass = Yes HD'),
#  Text(136.9798087141339, 184.43571428571428, 'LOAN_PURPOSE_RADIO_TV <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]\nclass = Yes HD'),
#  Text(135.2008501594049, 165.02142857142854, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = Yes HD'),
#  Text(138.7587672688629, 165.02142857142854, 'AGE <= 36.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(136.9798087141339, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(140.53772582359193, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(140.53772582359193, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(152.990435706695, 203.85, 'LOAN_AMOUNT <= 2810.5\ngini = 0.437\nsamples = 62\nvalue = [20, 42]\nclass = Yes HD'),
#  Text(147.65356004250796, 184.43571428571428, 'LOAN_AMOUNT <= 2547.0\ngini = 0.494\nsamples = 27\nvalue = [12, 15]\nclass = Yes HD'),
#  Text(145.87460148777896, 165.02142857142854, 'PAYMENT_TERM <= 732.0\ngini = 0.454\nsamples = 23\nvalue = [8, 15]\nclass = Yes HD'),
#  Text(144.09564293304993, 145.60714285714283, 'AGE <= 32.5\ngini = 0.494\nsamples = 18\nvalue = [8, 10]\nclass = Yes HD'),
#  Text(142.31668437832093, 126.19285714285712, 'LOAN_AMOUNT <= 380.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = Yes HD'),
#  Text(140.53772582359193, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(144.09564293304993, 106.77857142857141, 'LOAN_AMOUNT <= 1841.0\ngini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = Yes HD'),
#  Text(142.31668437832093, 87.3642857142857, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(145.87460148777896, 87.3642857142857, 'PAYMENT_TERM <= 640.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = No HD'),
#  Text(144.09564293304993, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(147.65356004250796, 67.94999999999999, 'CURRENT_RESIDENCE_DURATION <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(145.87460148777896, 48.53571428571428, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(149.432518597237, 48.53571428571428, 'PROPERTY_CAR_OTHER <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(147.65356004250796, 29.121428571428567, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(151.211477151966, 29.121428571428567, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(145.87460148777896, 126.19285714285712, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(147.65356004250796, 145.60714285714283, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(149.432518597237, 165.02142857142854, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(158.32731137088203, 184.43571428571428, 'CURRENT_RESIDENCE_DURATION <= 2.5\ngini = 0.353\nsamples = 35\nvalue = [8, 27]\nclass = Yes HD'),
#  Text(154.76939426142403, 165.02142857142854, 'LOAN_PURPOSE_EDUCATION <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Yes HD'),
#  Text(152.990435706695, 145.60714285714283, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Yes HD'),
#  Text(156.54835281615303, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(161.88522848034006, 165.02142857142854, 'LOAN_PURPOSE_REPAIRS <= 0.5\ngini = 0.423\nsamples = 23\nvalue = [7, 16]\nclass = Yes HD'),
#  Text(160.10626992561106, 145.60714285714283, 'LOAN_AMOUNT <= 3922.5\ngini = 0.397\nsamples = 22\nvalue = [6, 16]\nclass = Yes HD'),
#  Text(158.32731137088203, 126.19285714285712, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(161.88522848034006, 126.19285714285712, 'AGE <= 38.5\ngini = 0.469\nsamples = 16\nvalue = [6, 10]\nclass = Yes HD'),
#  Text(158.32731137088203, 106.77857142857141, 'PROPERTY_CAR_OTHER <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = No HD'),
#  Text(156.54835281615303, 87.3642857142857, 'LOAN_AMOUNT <= 4687.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Yes HD'),
#  Text(154.76939426142403, 67.94999999999999, 'EMPLOYMENT_DURATION <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(152.990435706695, 48.53571428571428, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(156.54835281615303, 48.53571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(158.32731137088203, 67.94999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(160.10626992561106, 87.3642857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(165.4431455897981, 106.77857142857141, 'PROPERTY_UNKNOWN <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Yes HD'),
#  Text(163.66418703506906, 87.3642857142857, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(167.2221041445271, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(163.66418703506906, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(169.0010626992561, 242.67857142857142, 'CURRENT_RESIDENCE_DURATION <= 2.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]\nclass = Yes HD'),
#  Text(165.4431455897981, 223.2642857142857, 'LOAN_AMOUNT <= 1590.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Yes HD'),
#  Text(163.66418703506906, 203.85, 'HOUSING_OWN <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(161.88522848034006, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(165.4431455897981, 184.43571428571428, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(167.2221041445271, 203.85, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(172.55897980871413, 223.2642857142857, 'LOAN_AMOUNT <= 566.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = No HD'),
#  Text(170.78002125398513, 203.85, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(174.33793836344313, 203.85, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(185.90116896918173, 281.50714285714287, 'AGE <= 38.5\ngini = 0.452\nsamples = 81\nvalue = [28, 53]\nclass = Yes HD'),
#  Text(181.4537725823592, 262.09285714285716, 'PAYMENT_TERM <= 457.5\ngini = 0.495\nsamples = 60\nvalue = [27, 33]\nclass = Yes HD'),
#  Text(177.89585547290116, 242.67857142857142, 'LOAN_AMOUNT <= 764.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = No HD'),
#  Text(176.11689691817216, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(179.6748140276302, 223.2642857142857, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(185.01168969181722, 242.67857142857142, 'JOB_TYPE <= 1.5\ngini = 0.483\nsamples = 54\nvalue = [22, 32]\nclass = Yes HD'),
#  Text(183.2327311370882, 223.2642857142857, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(186.79064824654623, 223.2642857142857, 'PAYMENT_TERM <= 604.5\ngini = 0.498\nsamples = 47\nvalue = [22, 25]\nclass = Yes HD'),
#  Text(177.89585547290116, 203.85, 'HOUSING_OWN <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = No HD'),
#  Text(176.11689691817216, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(179.6748140276302, 184.43571428571428, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = No HD'),
#  Text(177.89585547290116, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(181.4537725823592, 165.02142857142854, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No HD'),
#  Text(195.6854410201913, 203.85, 'AGE <= 31.5\ngini = 0.478\nsamples = 38\nvalue = [15, 23]\nclass = Yes HD'),
#  Text(186.79064824654623, 184.43571428571428, 'LOAN_AMOUNT <= 1131.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = No HD'),
#  Text(185.01168969181722, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(188.56960680127523, 165.02142857142854, 'PAYMENT_TERM <= 625.0\ngini = 0.444\nsamples = 12\nvalue = [8, 4]\nclass = No HD'),
#  Text(186.79064824654623, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(190.34856535600426, 145.60714285714283, 'EMPLOYMENT_DURATION <= 3.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = No HD'),
#  Text(186.79064824654623, 126.19285714285712, 'LOAN_PURPOSE_RADIO_TV <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = No HD'),
#  Text(185.01168969181722, 106.77857142857141, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No HD'),
#  Text(188.56960680127523, 106.77857142857141, 'AGE <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(186.79064824654623, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(190.34856535600426, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(193.90648246546226, 126.19285714285712, 'TELEPHONE <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(192.12752391073326, 106.77857142857141, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(195.6854410201913, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(204.58023379383633, 184.43571428571428, 'HOUSING_OWN <= 0.5\ngini = 0.403\nsamples = 25\nvalue = [7, 18]\nclass = Yes HD'),
#  Text(201.02231668437832, 165.02142857142854, 'AGE <= 34.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = No HD'),
#  Text(199.2433581296493, 145.60714285714283, 'LOAN_AMOUNT <= 3814.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(197.4643995749203, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(201.02231668437832, 126.19285714285712, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(202.80127523910733, 145.60714285714283, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(208.13815090329436, 165.02142857142854, 'LOAN_AMOUNT <= 6488.0\ngini = 0.208\nsamples = 17\nvalue = [2, 15]\nclass = Yes HD'),
#  Text(206.35919234856536, 145.60714285714283, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Yes HD'),
#  Text(209.91710945802336, 145.60714285714283, 'PROPERTY_CAR_OTHER <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Yes HD'),
#  Text(208.13815090329436, 126.19285714285712, 'AGE <= 36.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(206.35919234856536, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(209.91710945802336, 106.77857142857141, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(211.6960680127524, 126.19285714285712, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(190.34856535600426, 262.09285714285716, 'LOAN_PURPOSE_APPLIANCES <= 0.5\ngini = 0.091\nsamples = 21\nvalue = [1, 20]\nclass = Yes HD'),
#  Text(188.56960680127523, 242.67857142857142, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]\nclass = Yes HD'),
#  Text(192.12752391073326, 242.67857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(245.16272582359193, 320.3357142857143, 'CURRENT_RESIDENCE_DURATION <= 2.5\ngini = 0.459\nsamples = 219\nvalue = [78, 141]\nclass = Yes HD'),
#  Text(216.58820403825717, 300.9214285714286, 'OTHERS_ON_LOAN_NONE <= 0.5\ngini = 0.346\nsamples = 81\nvalue = [18, 63]\nclass = Yes HD'),
#  Text(209.91710945802336, 281.50714285714287, 'EMPLOYMENT_DURATION <= 8.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = No HD'),
#  Text(208.13815090329436, 262.09285714285716, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(211.6960680127524, 262.09285714285716, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(223.25929861849096, 281.50714285714287, 'HOUSING_RENT <= 0.5\ngini = 0.287\nsamples = 75\nvalue = [13, 62]\nclass = Yes HD'),
#  Text(215.25398512221042, 262.09285714285716, 'LOAN_PURPOSE_CAR_NEW <= 0.5\ngini = 0.188\nsamples = 57\nvalue = [6, 51]\nclass = Yes HD'),
#  Text(209.91710945802336, 242.67857142857142, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.085\nsamples = 45\nvalue = [2, 43]\nclass = Yes HD'),
#  Text(208.13815090329436, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(211.6960680127524, 223.2642857142857, 'LOAN_AMOUNT <= 798.5\ngini = 0.044\nsamples = 44\nvalue = [1, 43]\nclass = Yes HD'),
#  Text(209.91710945802336, 203.85, 'LOAN_AMOUNT <= 413.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Yes HD'),
#  Text(208.13815090329436, 184.43571428571428, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(211.6960680127524, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(213.4750265674814, 203.85, 'gini = 0.0\nsamples = 37\nvalue = [0, 37]\nclass = Yes HD'),
#  Text(220.59086078639746, 242.67857142857142, 'LOAN_AMOUNT <= 3650.0\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = Yes HD'),
#  Text(218.81190223166843, 223.2642857142857, 'AGE <= 36.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Yes HD'),
#  Text(217.03294367693942, 203.85, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(220.59086078639746, 203.85, 'AGE <= 39.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(218.81190223166843, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(222.36981934112646, 184.43571428571428, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(222.36981934112646, 223.2642857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(231.26461211477152, 262.09285714285716, 'AGE <= 37.0\ngini = 0.475\nsamples = 18\nvalue = [7, 11]\nclass = Yes HD'),
#  Text(227.7066950053135, 242.67857142857142, 'LOAN_AMOUNT <= 1047.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Yes HD'),
#  Text(225.9277364505845, 223.2642857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(229.4856535600425, 223.2642857142857, 'LOAN_AMOUNT <= 1072.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Yes HD'),
#  Text(227.7066950053135, 203.85, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(231.26461211477152, 203.85, 'PAYMENT_TERM <= 555.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Yes HD'),
#  Text(229.4856535600425, 184.43571428571428, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(233.04357066950053, 184.43571428571428, 'PROPERTY_UNKNOWN <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(231.26461211477152, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(234.82252922422953, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(234.82252922422953, 242.67857142857142, 'LOAN_AMOUNT <= 957.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = No HD'),
#  Text(233.04357066950053, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(236.60148777895856, 223.2642857142857, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(273.7372476089267, 300.9214285714286, 'AGE <= 38.5\ngini = 0.491\nsamples = 138\nvalue = [60, 78]\nclass = Yes HD'),
#  Text(259.28320935175344, 281.50714285714287, 'PAYMENT_TERM <= 518.5\ngini = 0.471\nsamples = 92\nvalue = [35, 57]\nclass = Yes HD'),
#  Text(249.94367693942613, 262.09285714285716, 'PAYMENT_TERM <= 350.5\ngini = 0.381\nsamples = 43\nvalue = [11, 32]\nclass = Yes HD'),
#  Text(241.9383634431456, 242.67857142857142, 'JOB_TYPE <= 2.5\ngini = 0.494\nsamples = 18\nvalue = [8, 10]\nclass = Yes HD'),
#  Text(240.15940488841656, 223.2642857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(243.7173219978746, 223.2642857142857, 'LOAN_AMOUNT <= 1310.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = No HD'),
#  Text(240.15940488841656, 203.85, 'AGE <= 29.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(238.38044633368756, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(241.9383634431456, 184.43571428571428, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(247.27523910733262, 203.85, 'LOAN_PURPOSE_APPLIANCES <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = No HD'),
#  Text(245.49628055260362, 184.43571428571428, 'EMPLOYMENT_DURATION <= 7.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = No HD'),
#  Text(243.7173219978746, 165.02142857142854, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No HD'),
#  Text(247.27523910733262, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(249.05419766206163, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(257.94899043570666, 242.67857142857142, 'AGE <= 30.5\ngini = 0.211\nsamples = 25\nvalue = [3, 22]\nclass = Yes HD'),
#  Text(256.17003188097766, 223.2642857142857, 'PROPERTY_SAVINGS_INSURANCE <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]\nclass = Yes HD'),
#  Text(254.39107332624866, 203.85, 'LOAN_PURPOSE_CAR_USED <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Yes HD'),
#  Text(252.61211477151966, 184.43571428571428, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(256.17003188097766, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(257.94899043570666, 203.85, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(259.7279489904357, 223.2642857142857, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = Yes HD'),
#  Text(268.6227417640808, 262.09285714285716, 'HOUSING_RENT <= 0.5\ngini = 0.5\nsamples = 49\nvalue = [24, 25]\nclass = Yes HD'),
#  Text(266.8437832093517, 242.67857142857142, 'PROPERTY_UNKNOWN <= 0.5\ngini = 0.494\nsamples = 45\nvalue = [20, 25]\nclass = Yes HD'),
#  Text(265.0648246546227, 223.2642857142857, 'LOAN_PURPOSE_RETRAINING <= 0.5\ngini = 0.482\nsamples = 42\nvalue = [17, 25]\nclass = Yes HD'),
#  Text(261.5069075451647, 203.85, 'AGE <= 29.5\ngini = 0.456\nsamples = 37\nvalue = [13, 24]\nclass = Yes HD'),
#  Text(259.7279489904357, 184.43571428571428, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(263.2858660998937, 184.43571428571428, 'LOAN_AMOUNT <= 3285.0\ngini = 0.482\nsamples = 32\nvalue = [13, 19]\nclass = Yes HD'),
#  Text(256.17003188097766, 165.02142857142854, 'PAYMENT_TERM <= 610.0\ngini = 0.498\nsamples = 17\nvalue = [9, 8]\nclass = No HD'),
#  Text(252.61211477151966, 145.60714285714283, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = No HD'),
#  Text(250.83315621679066, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(254.39107332624866, 126.19285714285712, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(259.7279489904357, 145.60714285714283, 'LOAN_AMOUNT <= 3176.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]\nclass = Yes HD'),
#  Text(257.94899043570666, 126.19285714285712, 'LOAN_PURPOSE_CAR_USED <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Yes HD'),
#  Text(256.17003188097766, 106.77857142857141, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(259.7279489904357, 106.77857142857141, 'LOAN_AMOUNT <= 2015.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(257.94899043570666, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(261.5069075451647, 87.3642857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(261.5069075451647, 126.19285714285712, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(270.4017003188098, 165.02142857142854, 'LOAN_AMOUNT <= 5525.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = Yes HD'),
#  Text(266.8437832093517, 145.60714285714283, 'AGE <= 37.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Yes HD'),
#  Text(265.0648246546227, 126.19285714285712, 'EMPLOYMENT_DURATION <= 11.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Yes HD'),
#  Text(263.2858660998937, 106.77857142857141, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Yes HD'),
#  Text(266.8437832093517, 106.77857142857141, 'CURRENT_RESIDENCE_DURATION <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(265.0648246546227, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(268.6227417640808, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(268.6227417640808, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(273.9596174282678, 145.60714285714283, 'LOAN_AMOUNT <= 6313.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(272.1806588735388, 126.19285714285712, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(275.7385759829968, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(268.6227417640808, 203.85, 'PAYMENT_TERM <= 579.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = No HD'),
#  Text(266.8437832093517, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(270.4017003188098, 184.43571428571428, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(268.6227417640808, 223.2642857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(270.4017003188098, 242.67857142857142, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(288.19128586609986, 281.50714285714287, 'PROPERTY_UNKNOWN <= 0.5\ngini = 0.496\nsamples = 46\nvalue = [25, 21]\nclass = No HD'),
#  Text(286.41232731137086, 262.09285714285716, 'PAYMENT_TERM <= 518.5\ngini = 0.5\nsamples = 41\nvalue = [20, 21]\nclass = Yes HD'),
#  Text(281.07545164718385, 242.67857142857142, 'PAYMENT_TERM <= 397.0\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = No HD'),
#  Text(279.29649309245485, 223.2642857142857, 'PAYMENT_TERM <= 263.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = No HD'),
#  Text(277.5175345377258, 203.85, 'LOAN_PURPOSE_FURNITURE <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = No HD'),
#  Text(275.7385759829968, 184.43571428571428, 'LOAN_AMOUNT <= 5724.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = No HD'),
#  Text(273.9596174282678, 165.02142857142854, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(277.5175345377258, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(279.29649309245485, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(281.07545164718385, 203.85, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(282.85441020191286, 223.2642857142857, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(291.7492029755579, 242.67857142857142, 'CURRENT_RESIDENCE_DURATION <= 3.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]\nclass = Yes HD'),
#  Text(286.41232731137086, 223.2642857142857, 'LOAN_PURPOSE_VACATION <= 0.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]\nclass = Yes HD'),
#  Text(284.63336875664186, 203.85, 'LOAN_AMOUNT <= 1276.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Yes HD'),
#  Text(282.85441020191286, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(286.41232731137086, 184.43571428571428, 'LOAN_AMOUNT <= 6267.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Yes HD'),
#  Text(284.63336875664186, 165.02142857142854, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(288.19128586609986, 165.02142857142854, 'LOAN_AMOUNT <= 6437.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(286.41232731137086, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(289.9702444208289, 145.60714285714283, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(288.19128586609986, 203.85, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(297.0860786397449, 223.2642857142857, 'PAYMENT_TERM <= 762.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]\nclass = No HD'),
#  Text(295.3071200850159, 203.85, 'AGE <= 41.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = No HD'),
#  Text(293.5281615302869, 184.43571428571428, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(297.0860786397449, 184.43571428571428, 'LOAN_PURPOSE_FURNITURE <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = No HD'),
#  Text(295.3071200850159, 165.02142857142854, 'LOAN_PURPOSE_RETRAINING <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(293.5281615302869, 145.60714285714283, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(297.0860786397449, 145.60714285714283, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(298.865037194474, 165.02142857142854, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(298.865037194474, 203.85, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(289.9702444208289, 262.09285714285716, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(334.88894792773647, 339.75, 'PAYMENT_TERM <= 579.5\ngini = 0.052\nsamples = 486\nvalue = [13, 473]\nclass = Yes HD'),
#  Text(318.87832093517534, 320.3357142857143, 'DEPENDENTS <= 1.5\ngini = 0.028\nsamples = 415\nvalue = [6, 409]\nclass = Yes HD'),
#  Text(312.20722635494155, 300.9214285714286, 'EMPLOYMENT_DURATION <= 5.5\ngini = 0.02\nsamples = 394\nvalue = [4, 390]\nclass = Yes HD'),
#  Text(305.98087141339, 281.50714285714287, 'AGE <= 31.5\ngini = 0.011\nsamples = 364\nvalue = [2, 362]\nclass = Yes HD'),
#  Text(304.201912858661, 262.09285714285716, 'gini = 0.0\nsamples = 295\nvalue = [0, 295]\nclass = Yes HD'),
#  Text(307.759829968119, 262.09285714285716, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.056\nsamples = 69\nvalue = [2, 67]\nclass = Yes HD'),
#  Text(305.98087141339, 242.67857142857142, 'LOAN_AMOUNT <= 2093.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Yes HD'),
#  Text(304.201912858661, 223.2642857142857, 'HOUSING_OWN <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Yes HD'),
#  Text(302.422954303932, 203.85, 'PAYMENT_TERM <= 152.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(300.643995749203, 184.43571428571428, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(304.201912858661, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(305.98087141339, 203.85, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(307.759829968119, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(309.53878852284805, 242.67857142857142, 'gini = 0.0\nsamples = 56\nvalue = [0, 56]\nclass = Yes HD'),
#  Text(318.43358129649306, 281.50714285714287, 'JOB_TYPE <= 0.5\ngini = 0.124\nsamples = 30\nvalue = [2, 28]\nclass = Yes HD'),
#  Text(314.87566418703506, 262.09285714285716, 'LOAN_PURPOSE_FURNITURE <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(313.09670563230605, 242.67857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(316.65462274176406, 242.67857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(321.9914984059511, 262.09285714285716, 'TELEPHONE <= 0.5\ngini = 0.069\nsamples = 28\nvalue = [1, 27]\nclass = Yes HD'),
#  Text(320.2125398512221, 242.67857142857142, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]\nclass = Yes HD'),
#  Text(323.7704569606801, 242.67857142857142, 'PAYMENT_TERM <= 366.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(321.9914984059511, 223.2642857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(325.5494155154091, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(325.5494155154091, 300.9214285714286, 'JOB_TYPE <= 2.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]\nclass = Yes HD'),
#  Text(323.7704569606801, 281.50714285714287, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Yes HD'),
# ...
#  Text(740.7138682252922, 203.85, 'PAYMENT_TERM <= 1113.0\ngini = 0.451\nsamples = 64\nvalue = [42, 22]\nclass = No HD'),
#  Text(733.375664187035, 184.43571428571428, 'PAYMENT_TERM <= 960.5\ngini = 0.486\nsamples = 48\nvalue = [28, 20]\nclass = No HD'),
#  Text(728.4835281615302, 165.02142857142854, 'LOAN_AMOUNT <= 3771.0\ngini = 0.291\nsamples = 17\nvalue = [14, 3]\nclass = No HD'),
#  Text(726.7045696068012, 145.60714285714283, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = No HD'),
#  Text(724.9256110520722, 126.19285714285712, 'EMPLOYMENT_DURATION <= 1.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(723.1466524973432, 106.77857142857141, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(726.7045696068012, 106.77857142857141, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(728.4835281615302, 126.19285714285712, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(730.2624867162593, 145.60714285714283, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = No HD'),
#  Text(738.2678002125398, 165.02142857142854, 'LOAN_AMOUNT <= 4178.5\ngini = 0.495\nsamples = 31\nvalue = [14, 17]\nclass = Yes HD'),
#  Text(733.8204038257173, 145.60714285714283, 'AGE <= 33.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = No HD'),
#  Text(732.0414452709883, 126.19285714285712, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(735.5993623804463, 126.19285714285712, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No HD'),
#  Text(742.7151965993623, 145.60714285714283, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.408\nsamples = 21\nvalue = [6, 15]\nclass = Yes HD'),
#  Text(739.1572794899043, 126.19285714285712, 'EMPLOYMENT_DURATION <= 6.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = No HD'),
#  Text(737.3783209351753, 106.77857142857141, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(740.9362380446333, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(746.2731137088203, 126.19285714285712, 'FOREIGN_WORKER <= 0.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]\nclass = Yes HD'),
#  Text(744.4941551540913, 106.77857142857141, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(748.0520722635493, 106.77857142857141, 'LOAN_PURPOSE_BUSINESS <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]\nclass = Yes HD'),
#  Text(746.2731137088203, 87.3642857142857, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Yes HD'),
#  Text(749.8310308182785, 87.3642857142857, 'LOAN_AMOUNT <= 6466.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(748.0520722635493, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(751.6099893730075, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(748.0520722635493, 184.43571428571428, 'FOREIGN_WORKER <= 0.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = No HD'),
#  Text(746.2731137088203, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(749.8310308182785, 165.02142857142854, 'LOAN_PURPOSE_VACATION <= 0.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = No HD'),
#  Text(748.0520722635493, 145.60714285714283, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = No HD'),
#  Text(751.6099893730075, 145.60714285714283, 'CURRENT_RESIDENCE_DURATION <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(749.8310308182785, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(753.3889479277365, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(765.8416578108395, 223.2642857142857, 'LOAN_PURPOSE_VACATION <= 0.5\ngini = 0.423\nsamples = 23\nvalue = [7, 16]\nclass = Yes HD'),
#  Text(764.0626992561105, 203.85, 'LOAN_AMOUNT <= 5815.0\ngini = 0.363\nsamples = 21\nvalue = [5, 16]\nclass = Yes HD'),
#  Text(762.2837407013815, 184.43571428571428, 'LOAN_AMOUNT <= 5595.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]\nclass = Yes HD'),
#  Text(760.5047821466525, 165.02142857142854, 'PAYMENT_TERM <= 1100.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]\nclass = Yes HD'),
#  Text(758.7258235919235, 145.60714285714283, 'EMPLOYMENT_DURATION <= 5.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = Yes HD'),
#  Text(756.9468650371945, 126.19285714285712, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(760.5047821466525, 126.19285714285712, 'AGE <= 39.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = No HD'),
#  Text(758.7258235919235, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(762.2837407013815, 106.77857142857141, 'PAYMENT_TERM <= 1082.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(760.5047821466525, 87.3642857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(764.0626992561105, 87.3642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(762.2837407013815, 145.60714285714283, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(764.0626992561105, 165.02142857142854, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(765.8416578108395, 184.43571428571428, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(767.6206163655685, 203.85, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(779.183846971307, 320.3357142857143, 'INSTALLMENT_PERCENT <= 4.5\ngini = 0.375\nsamples = 44\nvalue = [33, 11]\nclass = No HD'),
#  Text(777.404888416578, 300.9214285714286, 'EMPLOYMENT_DURATION <= 10.5\ngini = 0.444\nsamples = 33\nvalue = [22, 11]\nclass = No HD'),
#  Text(775.625929861849, 281.50714285714287, 'LOAN_AMOUNT <= 5226.5\ngini = 0.412\nsamples = 31\nvalue = [22, 9]\nclass = No HD'),
#  Text(769.3995749202976, 262.09285714285716, 'EMPLOYMENT_DURATION <= 4.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = No HD'),
#  Text(767.6206163655685, 242.67857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(771.1785334750266, 242.67857142857142, 'PAYMENT_TERM <= 808.0\ngini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = No HD'),
#  Text(769.3995749202976, 223.2642857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(772.9574920297556, 223.2642857142857, 'PROPERTY_CAR_OTHER <= 0.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = No HD'),
#  Text(771.1785334750266, 203.85, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(774.7364505844846, 203.85, 'TELEPHONE <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = No HD'),
#  Text(772.9574920297556, 184.43571428571428, 'AGE <= 54.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(771.1785334750266, 165.02142857142854, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(774.7364505844846, 165.02142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(776.5154091392136, 184.43571428571428, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(781.8522848034006, 262.09285714285716, 'PAYMENT_TERM <= 808.0\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = No HD'),
#  Text(778.2943676939426, 242.67857142857142, 'LOAN_PURPOSE_BUSINESS <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(776.5154091392136, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(780.0733262486716, 223.2642857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(785.4102019128586, 242.67857142857142, 'JOB_TYPE <= 2.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = No HD'),
#  Text(783.6312433581296, 223.2642857142857, 'EMPLOYMENT_DURATION <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(781.8522848034006, 203.85, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(785.4102019128586, 203.85, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(787.1891604675876, 223.2642857142857, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = No HD'),
#  Text(779.183846971307, 281.50714285714287, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(780.9628055260362, 300.9214285714286, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = No HD'),
#  Text(815.485719978746, 339.75, 'PAYMENT_TERM <= 945.0\ngini = 0.413\nsamples = 134\nvalue = [95, 39]\nclass = No HD'),
#  Text(806.4241498405951, 320.3357142857143, 'INSTALLMENT_PERCENT <= 4.5\ngini = 0.485\nsamples = 70\nvalue = [41, 29]\nclass = No HD'),
#  Text(798.9747608926674, 300.9214285714286, 'LOAN_AMOUNT <= 4165.0\ngini = 0.499\nsamples = 59\nvalue = [31, 28]\nclass = No HD'),
#  Text(792.5260361317747, 281.50714285714287, 'HOUSING_FREE <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = No HD'),
#  Text(790.7470775770457, 262.09285714285716, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = No HD'),
#  Text(788.9681190223166, 242.67857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(792.5260361317747, 242.67857142857142, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = No HD'),
#  Text(794.3049946865037, 262.09285714285716, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(805.4234856535601, 281.50714285714287, 'AGE <= 53.5\ngini = 0.494\nsamples = 47\nvalue = [21, 26]\nclass = Yes HD'),
#  Text(800.5313496280553, 262.09285714285716, 'CURRENT_RESIDENCE_DURATION <= 4.5\ngini = 0.469\nsamples = 40\nvalue = [15, 25]\nclass = Yes HD'),
#  Text(796.0839532412327, 242.67857142857142, 'AGE <= 37.5\ngini = 0.431\nsamples = 35\nvalue = [11, 24]\nclass = Yes HD'),
#  Text(794.3049946865037, 223.2642857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(797.8629117959617, 223.2642857142857, 'AGE <= 50.5\ngini = 0.464\nsamples = 30\nvalue = [11, 19]\nclass = Yes HD'),
#  Text(794.3049946865037, 203.85, 'LOAN_AMOUNT <= 7103.5\ngini = 0.499\nsamples = 21\nvalue = [10, 11]\nclass = Yes HD'),
#  Text(792.5260361317747, 184.43571428571428, 'LOAN_AMOUNT <= 6499.0\ngini = 0.494\nsamples = 18\nvalue = [10, 8]\nclass = No HD'),
#  Text(790.7470775770457, 165.02142857142854, 'EMPLOYMENT_DURATION <= 5.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]\nclass = Yes HD'),
#  Text(787.1891604675876, 145.60714285714283, 'DEPENDENTS <= 1.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = No HD'),
#  Text(785.4102019128586, 126.19285714285712, 'EMPLOYMENT_DURATION <= 4.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Yes HD'),
#  Text(783.6312433581296, 106.77857142857141, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(787.1891604675876, 106.77857142857141, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(788.9681190223166, 126.19285714285712, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(794.3049946865037, 145.60714285714283, 'CURRENT_RESIDENCE_DURATION <= 2.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Yes HD'),
#  Text(792.5260361317747, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(796.0839532412327, 126.19285714285712, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(794.3049946865037, 165.02142857142854, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(796.0839532412327, 184.43571428571428, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(801.4208289054197, 203.85, 'LOAN_AMOUNT <= 7601.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Yes HD'),
#  Text(799.6418703506907, 184.43571428571428, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(803.1997874601487, 184.43571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(804.9787460148777, 242.67857142857142, 'EMPLOYMENT_DURATION <= 5.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = No HD'),
#  Text(803.1997874601487, 223.2642857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(806.7577045696067, 223.2642857142857, 'AGE <= 47.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(804.9787460148777, 203.85, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(808.5366631243357, 203.85, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(810.3156216790649, 262.09285714285716, 'LOAN_PURPOSE_BUSINESS <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = No HD'),
#  Text(808.5366631243357, 242.67857142857142, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No HD'),
#  Text(812.0945802337939, 242.67857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(813.8735387885229, 300.9214285714286, 'LOAN_PURPOSE_BUSINESS <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = No HD'),
#  Text(812.0945802337939, 281.50714285714287, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = No HD'),
#  Text(815.6524973432519, 281.50714285714287, 'TELEPHONE <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(813.8735387885229, 262.09285714285716, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(817.4314558979809, 262.09285714285716, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(824.5472901168969, 320.3357142857143, 'AGE <= 31.5\ngini = 0.264\nsamples = 64\nvalue = [54, 10]\nclass = No HD'),
#  Text(820.9893730074389, 300.9214285714286, 'HOUSING_OWN <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(819.2104144527099, 281.50714285714287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(822.7683315621679, 281.50714285714287, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(828.1052072263549, 300.9214285714286, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.206\nsamples = 60\nvalue = [53, 7]\nclass = No HD'),
#  Text(826.3262486716259, 281.50714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(829.884165781084, 281.50714285714287, 'PAYMENT_TERM <= 1021.5\ngini = 0.183\nsamples = 59\nvalue = [53, 6]\nclass = No HD'),
#  Text(828.1052072263549, 262.09285714285716, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = No HD'),
#  Text(831.663124335813, 262.09285714285716, 'HOUSING_RENT <= 0.5\ngini = 0.266\nsamples = 38\nvalue = [32, 6]\nclass = No HD'),
#  Text(829.884165781084, 242.67857142857142, 'EMPLOYMENT_DURATION <= 8.5\ngini = 0.234\nsamples = 37\nvalue = [32, 5]\nclass = No HD'),
#  Text(828.1052072263549, 223.2642857142857, 'LOAN_PURPOSE_RETRAINING <= 0.5\ngini = 0.311\nsamples = 26\nvalue = [21, 5]\nclass = No HD'),
#  Text(826.3262486716259, 203.85, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.269\nsamples = 25\nvalue = [21, 4]\nclass = No HD'),
#  Text(824.5472901168969, 184.43571428571428, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = No HD'),
#  Text(828.1052072263549, 184.43571428571428, 'CURRENT_RESIDENCE_DURATION <= 3.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]\nclass = No HD'),
#  Text(822.7683315621679, 165.02142857142854, 'AGE <= 44.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = No HD'),
#  Text(820.9893730074389, 145.60714285714283, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(824.5472901168969, 145.60714285714283, 'PAYMENT_TERM <= 1155.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(822.7683315621679, 126.19285714285712, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(826.3262486716259, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(833.442082890542, 165.02142857142854, 'EMPLOYMENT_DURATION <= 4.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = No HD'),
#  Text(831.663124335813, 145.60714285714283, 'LOAN_PURPOSE_RADIO_TV <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(829.884165781084, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(833.442082890542, 126.19285714285712, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(835.221041445271, 145.60714285714283, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No HD'),
#  ...]

# %%
plot_confusion_matrix(model, X_test, y_test, display_labels=["No Allow", "Allow"])
# Out:
# C:\Users\a362014\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
path = model.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas
ccp_alphas = ccp_alphas[:-1]

model_dts = []

for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    model.fit(X_train, y_train)
    model_dts.append(model)

# %%
train_scores = [model.score(X_train, y_train) for model in model_dts]
test_scores = [model.score(X_test, y_test) for model in model_dts]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker='o', label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test", drawstyle="steps-post")
ax.legend()
plt.show()

# %%
model = DecisionTreeClassifier(random_state=42, ccp_alpha=0.0025)
scores = cross_val_score(model, X_train, y_train, cv=5)
df1 = pd.DataFrame(data={'tree':range(5), 'accuracy':scores})
df1.plot(x='tree', y='accuracy', marker='o', linestyle='--')
# Out:
# <AxesSubplot:xlabel='tree'>

# %%
alpha_loop_values = []

for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    scores = cross_val_score(model, X_train, y_train, cv=5)
    alpha_loop_values.append([ccp_alpha, np.mean(scores),np.std(scores)])

alpha_results = pd.DataFrame(alpha_loop_values, columns=['alpha','mean_accuracy','std'])
plt.figure(figsize=(15,7.5))
alpha_results.plot(x='alpha', y='mean_accuracy', yerr='std', marker='o', linestyle='--')
# Out:
# <AxesSubplot:xlabel='alpha'>

# %%
# alpha_results[(alpha_results['alpha'] > 0.001) & (alpha_results['alpha'] < 0.0034)]
temp2 = alpha_results[(alpha_results.mean_accuracy == alpha_results.mean_accuracy.max())]
temp3 = temp2[(temp2.alpha == temp2.alpha.max())]['alpha']

# %%
ideal_ccp_alpha = float(temp3)
ideal_ccp_alpha
# Out:
# 0.0023575435869288945

# %%
test_pct = 0.3 # Separaremos 30% dos dados para testes
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_pct)

model_pruned = DecisionTreeClassifier(random_state=42, ccp_alpha=ideal_ccp_alpha)
model_pruned.fit(X_train,y_train)

y_pred = model_pruned.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Acurácia do modelo (número de predições assertivas sobre número total de testes): {acc}")
# Out:
# Acurácia do modelo (número de predições assertivas sobre número total de testes): 0.7317972350230415

# %%
ConfusionMatrixDisplay.from_estimator(model_pruned, X_test, y_test, display_labels=["No Allow", "Allow"])

# %%
plt.figure(figsize=(15,7.5))
plot_tree(model_pruned, filled=True, rounded=True, class_names=["No Allow","Yes Allow"], feature_names=X.columns)
# Out:
# [Text(418.5, 378.5785714285714, 'LOAN_AMOUNT <= 4359.0\ngini = 0.45\nsamples = 2530\nvalue = [864, 1666]\nclass = Yes Allow'),
#  Text(171.20454545454547, 320.3357142857143, 'EMPLOYMENT_DURATION <= 4.5\ngini = 0.312\nsamples = 1579\nvalue = [305, 1274]\nclass = Yes Allow'),
#  Text(76.0909090909091, 262.09285714285716, 'PROPERTY_REAL_ESTATE <= 0.5\ngini = 0.209\nsamples = 1074\nvalue = [127, 947]\nclass = Yes Allow'),
#  Text(38.04545454545455, 203.85, 'gini = 0.291\nsamples = 640\nvalue = [113, 527]\nclass = Yes Allow'),
#  Text(114.13636363636364, 203.85, 'gini = 0.062\nsamples = 434\nvalue = [14, 420]\nclass = Yes Allow'),
#  Text(266.3181818181818, 262.09285714285716, 'AGE <= 37.5\ngini = 0.456\nsamples = 505\nvalue = [178, 327]\nclass = Yes Allow'),
#  Text(190.22727272727275, 203.85, 'LOAN_AMOUNT <= 2577.5\ngini = 0.374\nsamples = 293\nvalue = [73, 220]\nclass = Yes Allow'),
#  Text(152.1818181818182, 145.60714285714283, 'gini = 0.282\nsamples = 188\nvalue = [32, 156]\nclass = Yes Allow'),
#  Text(228.27272727272728, 145.60714285714283, 'LOAN_AMOUNT <= 2815.0\ngini = 0.476\nsamples = 105\nvalue = [41, 64]\nclass = Yes Allow'),
#  Text(190.22727272727275, 87.3642857142857, 'gini = 0.346\nsamples = 18\nvalue = [14, 4]\nclass = No Allow'),
#  Text(266.3181818181818, 87.3642857142857, 'gini = 0.428\nsamples = 87\nvalue = [27, 60]\nclass = Yes Allow'),
#  Text(342.40909090909093, 203.85, 'PAYMENT_TERM <= 1006.0\ngini = 0.5\nsamples = 212\nvalue = [105, 107]\nclass = Yes Allow'),
#  Text(304.3636363636364, 145.60714285714283, 'gini = 0.493\nsamples = 184\nvalue = [81, 103]\nclass = Yes Allow'),
#  Text(380.4545454545455, 145.60714285714283, 'gini = 0.245\nsamples = 28\nvalue = [24, 4]\nclass = No Allow'),
#  Text(665.7954545454546, 320.3357142857143, 'EMPLOYMENT_DURATION <= 7.5\ngini = 0.485\nsamples = 951\nvalue = [559, 392]\nclass = No Allow'),
#  Text(570.6818181818182, 262.09285714285716, 'AGE <= 35.5\ngini = 0.497\nsamples = 605\nvalue = [278, 327]\nclass = Yes Allow'),
#  Text(494.5909090909091, 203.85, 'PAYMENT_TERM <= 975.5\ngini = 0.382\nsamples = 140\nvalue = [36, 104]\nclass = Yes Allow'),
#  Text(456.54545454545456, 145.60714285714283, 'gini = 0.318\nsamples = 121\nvalue = [24, 97]\nclass = Yes Allow'),
#  Text(532.6363636363636, 145.60714285714283, 'gini = 0.465\nsamples = 19\nvalue = [12, 7]\nclass = No Allow'),
#  Text(646.7727272727273, 203.85, 'JOB_TYPE <= 2.5\ngini = 0.499\nsamples = 465\nvalue = [242, 223]\nclass = No Allow'),
#  Text(608.7272727272727, 145.60714285714283, 'gini = 0.475\nsamples = 196\nvalue = [76, 120]\nclass = Yes Allow'),
#  Text(684.8181818181819, 145.60714285714283, 'LOAN_AMOUNT <= 6038.5\ngini = 0.473\nsamples = 269\nvalue = [166, 103]\nclass = No Allow'),
#  Text(646.7727272727273, 87.3642857142857, 'EMPLOYMENT_DURATION <= 3.5\ngini = 0.5\nsamples = 162\nvalue = [82, 80]\nclass = No Allow'),
#  Text(608.7272727272727, 29.121428571428567, 'gini = 0.405\nsamples = 46\nvalue = [13, 33]\nclass = Yes Allow'),
#  Text(684.8181818181819, 29.121428571428567, 'gini = 0.482\nsamples = 116\nvalue = [69, 47]\nclass = No Allow'),
#  Text(722.8636363636364, 87.3642857142857, 'gini = 0.337\nsamples = 107\nvalue = [84, 23]\nclass = No Allow'),
#  Text(760.909090909091, 262.09285714285716, 'OTHERS_ON_LOAN_NONE <= 0.5\ngini = 0.305\nsamples = 346\nvalue = [281, 65]\nclass = No Allow'),
#  Text(722.8636363636364, 203.85, 'gini = 0.133\nsamples = 195\nvalue = [181, 14]\nclass = No Allow'),
#  Text(798.9545454545455, 203.85, 'gini = 0.447\nsamples = 151\nvalue = [100, 51]\nclass = No Allow')]

# %% [markdown]
# Apesar de estarmos utilizando somente algumas variáveis do dataset carregado, o desafio espera um modelo que aceite todas as variáveis dos conjuntos de dados disponíveis. Portanto, vamos utilizar um transformador para transformar os dados de entrada, removendo as colunas que não queremos, antes enviá-los ao nosso modelo. Dessa forma, criaremos uma `Pipeline`, que utiliza o transformador como entrada, e o nosso modelo em seguida.
#
# Fica como tarefa para você unir os outros conjuntos de dados disponíveis e utilizá-los também para predições no modelo, em vez de remover as colunas.

# %% [markdown]
# ## Sobre Pipelines
#
# Uma `Pipeline`, da biblioteca `scikit-learn`, consiste em uma série de passos onde realizamos transformações em dados. As transformações são definidas por classes que devem ter sempre **dois métodos**:
#
# - **fit**: Um método que recebe dados de treinamento, e retorna a própria instância da classe. Ele é aplicado quando se vai treinar utilizar uma Pipeline para treinar um modelo.
# - **transform**: Um método que recebe como entrada um conjunto de dados e deve retornar um outro conjunto de dados, transformado. Ele é aplicado em cada etapa da Pipeline, recebendo os dados do passo anterior e transformando-os.
#
# Veja abaixo uma representação gráfica do funcionamento de uma Pipeline:

# %% [markdown]
# ![](https://s3.br-sao.cloud-object-storage.appdomain.cloud/maratona-static/pipeline.png)

# %% [markdown]
# Nesse Notebook, vamos criar uma Pipeline muito similar ao exemplo acima, com dois estágios:
#
# - **drop_columns**: Remove as colunas indesejadas do conjunto de dados de entrada.
# - **classification**: Alimenta um modelo de classificação com os dados obtidos no estágio **drop_columns**, podendo ser tanto para treinamento quanto para obter uma predição.

# %% [markdown]
# ## Criação de Pipelines no scikit-learn
#
# Para criar um modelo capaz de fazer transformações nos dados de entrada, vamos criar uma `Pipeline` do `scikit-learn` e aplicar nossas transformações dentro dos estágios dela.
#
# Abaixo, definimos um transformador exemplo, que irá remover as colunas passadas como parâmetro em sua inicialização:

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline


# Um transformador para remover colunas indesejadas
class DropColumns(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        # Primeiro realizamos a cópia do DataFrame 'X' de entrada
        data = X.copy()
        # Retornamos um novo dataframe sem as colunas indesejadas
        return data.drop(labels=self.columns, axis='columns')

# %% [markdown]
# Tanto o método `fit` quanto o `transform` devem obrigatoriamente ser definidos, mesmo se não forem fazer nada de diferente, como no caso do `fit` acima.
#
# Da mesma forma, você pode criar outros transformadores, para outros propósitos, sempre herdando das classes `BaseEstimator` e `TransformerMixin`. Você pode utilizar um transformador para, por exemplo, criar novas colunas, editar tipos de dados de colunas existentes, entre outros.
#
# Agora, vamos criar uma Pipeline para utilização do nosso modelo, aceitando todas as colunas esperadas pelo desafio e removendo as que não queremos usar.

# %%
challenge_columns = ['ID', 'CHECKING_BALANCE', 'PAYMENT_TERM', 'CREDIT_HISTORY',
       'LOAN_PURPOSE', 'LOAN_AMOUNT', 'EXISTING_SAVINGS',
       'EMPLOYMENT_DURATION', 'INSTALLMENT_PERCENT', 'SEX', 'OTHERS_ON_LOAN',
       'CURRENT_RESIDENCE_DURATION', 'PROPERTY', 'AGE', 'INSTALLMENT_PLANS',
       'HOUSING', 'EXISTING_CREDITS_COUNT', 'JOB_TYPE', 'DEPENDENTS',
       'TELEPHONE', 'FOREIGN_WORKER', 'ALLOW']

unwanted_columns = list((set(challenge_columns) - set(target)) - set(features)) # Remover todas as colunas que não são features do nosso modelo

# %%
# Criando uma instância do transformador, passando como parâmetro as colunas que não queremos
drop_columns = DropColumns(unwanted_columns)


# Criando a Pipeline, adicionando o nosso transformador seguido de um modelo de árvore de decisão
skl_pipeline = Pipeline(steps=[('drop_columns', drop_columns), ('classification', model)])

# %% [markdown]
# Pronto! Essa pipeline agora está pronta para receber todas as variáveis do desafio, apesar de o modelo só usar algumas.

# %% [markdown]
# ## Deploy do modelo para o Watson Machine Learning (WML)
#
# Agora temos o modelo pronto para publicação, queremos deixá-lo online para que o sistema da Maratona possa testá-lo :)
#
# Para isso, vamos utilizar a biblioteca `IBM Watson Machine Learning`, que permite realizar o encapsulamento de modelos de Machine Learning em APIs REST.

# %%
# Instalar a biblioteca do WML
# !pip install -U ibm-watson-machine-learning

# %%
from ibm_watson_machine_learning import APIClient

# %% [markdown]
# Caso ainda não tiver criado, crie um serviço de Machine Learning aqui: https://cloud.ibm.com/catalog/services/machine-learning.
#
# Insira suas credenciais para o serviço na célula abaixo.
#
# Em `location`, insira o ID da região onde se encontra o seu serviço WML instanciado, de acordo com as possibilidades abaixo:
#
# - Dallas - `us-south`
# - London - `eu-gb`
# - Frankfurt - `eu-de`
# - Tokyo - `jp-tok`
#
# Para a API key, você deve gerá-la aqui: https://cloud.ibm.com/iam/apikeys. Não compartilhe-a com ninguém! Uma API key dá acesso à sua conta IBM Cloud.

# %%
api_key = 'INSIRA SUA API KEY AQUI'
location = 'us-south' # Caso o WML estiver em uma região diferente, altere

wml_credentials = {
    "apikey": api_key,
    "url": 'https://' + location + '.ml.cloud.ibm.com'
}

client = APIClient(wml_credentials)

# %% [markdown]
# Crie um espaço para salvar o seu modelo. Você pode criá-lo aqui: https://dataplatform.cloud.ibm.com/ml-runtime/spaces?context=cpdaas
#
# Quando criar o seu espaço, **associe a instância do seu serviço WML ao espaço!** Sem associar, você não conseguirá efetuar o deploy.

# %%
# Listar espaços criados na sua instância de WML
client.spaces.list(limit=10)

# %% [markdown]
# Copie o ID do seu espaço criado para o desafio e cole-o abaixo para utilizá-lo. Você deverá ver a mensagem 'SUCCESS' se o espaço estiver corretamente configurado.

# %%
space_id = 'cole aqui'
client.set.default_space(space_id)

# %% [markdown]
# ## Utilização da Pipeline dentro do Watson Machine Learning (WML)
#
# Para utilizar uma Pipeline no WML com transformadores customizados, são necessários alguns passos adicionais:
#
# 1. Criar um pacote no Python contendo o transformador customizado;
# 2. Carregar esse pacote com o transformador em um repositório no WML;
# 3. Criar uma especificação de software, com esse pacote customizado, que vai ser utilizada como tempo de execução do modelo no WML.
#
# Como exemplo, vamos utilizar um pacote já pronto, disponível aqui: https://github.com/vnderlev/watson-sklearn-transforms. Para configurar o pacote Python, são necessários alguns outros arquivos, mas a lógica do transformador criado se encontra [neste arquivo](https://github.com/vnderlev/watson-sklearn-transforms/blob/master/my_custom_sklearn_transforms/sklearn_transformers.py). No caso, esse é o mesmo transformador que definimos aqui, ele vai excluir do conjunto de dados as colunas passadas como parâmetro na sua inicialização.
#
# Abaixo, vamos baixar esse pacote do GitHub e instalá-lo no Python.

# %%
# !rm -rf watson-sklearn-transforms # Remover a pasta caso já exista
# !git clone https://github.com/vnderlev/watson-sklearn-transforms # Clonar o repositório com o pacote
# !zip -r drop-columns.zip watson-sklearn-transforms # Zipar o pacote
# !pip install drop-columns.zip # Instalar o pacote zipado

# %% [markdown]
# Vamos agora recriar nossa Pipeline utilizando esse pacote instalado.

# %%
from my_custom_sklearn_transforms.sklearn_transformers import DropColumns

drop_columns = DropColumns(unwanted_columns)

pipeline = Pipeline(steps=[('drop_columns', drop_columns), ('classification', model)])

# %% [markdown]
# Vamos agora subir o transformador customizado que baixamos para o WML.

# %%
# Metadados para o pacote customizado
meta_prop_pkg_extn = {
    client.package_extensions.ConfigurationMetaNames.NAME: "Drop_Columns",
    client.package_extensions.ConfigurationMetaNames.DESCRIPTION: "Extensão para remover colunas",
    client.package_extensions.ConfigurationMetaNames.TYPE: "pip_zip"
}

# Subir o pacote
pkg_extn_details = client.package_extensions.store(meta_props=meta_prop_pkg_extn, file_path="drop-columns.zip")

# Salvar as informações sobre o pacote
pkg_extn_uid = client.package_extensions.get_uid(pkg_extn_details)
pkg_extn_url = client.package_extensions.get_href(pkg_extn_details)

# %% [markdown]
# Vamos agora criar uma especificação de software com o nosso pacote customizado, para que o WML possa utilizar. Caso estiver utilizando um software diferente de `Python 3.8` ou biblioteca diferente de `scikit-learn`, você pode dar uma olhada na lista de especificações de software suportadas pelo WML: https://dataplatform.cloud.ibm.com/docs/content/wsj/wmls/wmls-deploy-python-types.html?context=analytics&audience=wdp

# %%
base_sw_spec_uid = client.software_specifications.get_uid_by_name("default_py3.8")

# Caso queira utilizar um software diferente de Python 3.8 como base, dê uma olhada nos disponíveis com a linha abaixo
# client.software_specifications.list(limit=100)

# %%
# Metadados da nova especificação de software
meta_prop_sw_spec = {
    client.software_specifications.ConfigurationMetaNames.NAME: "sw_spec_drop_columns",
    client.software_specifications.ConfigurationMetaNames.DESCRIPTION: "Software specification utilizando DropColumns",
    client.software_specifications.ConfigurationMetaNames.BASE_SOFTWARE_SPECIFICATION: {"guid": base_sw_spec_uid}
}

# Criando a nova especificação de software e obtendo seu ID
sw_spec_details = client.software_specifications.store(meta_props=meta_prop_sw_spec)
sw_spec_uid = client.software_specifications.get_uid(sw_spec_details)

# Adicionando o pacote customizado à nova especificação
client.software_specifications.add_package_extension(sw_spec_uid, pkg_extn_uid)

# %% [markdown]
# Finalmente, vamos publicar a pipeline utilizando a especificação de software customizada que criamos.

# %%
# Metadados do modelo
model_props = {
    client.repository.ModelMetaNames.NAME: "Modelo com Pipeline customizada",
    client.repository.ModelMetaNames.TYPE: 'scikit-learn_0.23',
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: sw_spec_uid
}

# Publicando a Pipeline como um modelo
published_model = client.repository.store_model(model=pipeline, meta_props=model_props)
published_model_uid = client.repository.get_model_uid(published_model)
client.repository.get_details(published_model_uid)

# %% [markdown]
# Seu modelo agora está salvo. Vamos agora deixá-lo disponível online, para que possamos testá-lo:

# %%
# Metadados para publicação do modelo
metadata = {
    client.deployments.ConfigurationMetaNames.NAME: "Publicação do modelo customizado",
    client.deployments.ConfigurationMetaNames.ONLINE: {}
}

# Publicar
created_deployment = client.deployments.create(published_model_uid, meta_props=metadata)

# %% [markdown]
# ## Parabéns!
#
# Seu modelo está agora publicado. Quando estiver pronto para submeter o desafio, você pode acessar https://maratona.dev/challenges/1, e utilizar as credenciais abaixo para realizar a submissão. Lembre-se de revisar todas as instruções no [README](https://github.com/maratonadev/desafio-1-2021) antes de submeter!

# %%
deployment_uid = client.deployments.get_uid(created_deployment)

print(f"Credenciais para envio (não compartilhe esses dados com ninguém!)\n\nAPI key: {api_key}\nDeployment ID: {deployment_uid}")
