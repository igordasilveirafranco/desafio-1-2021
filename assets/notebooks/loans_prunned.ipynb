# %% [markdown]
# # Desafio 1 - Maratona Behind the Code 2021
#
# ### Notebook guia
#
# Esse Jupyter Notebook te dará instruções para criar uma solução introdutória para o desafio 1 da Maratona. Sinta-se livre para editar e melhorar sua solução!

# %% [markdown]
# **Atenção: se estiver utilizando o Watson Studio, lembre-se de deixar o Notebook como editável, clicando no botão de editar acima.**
#
# ![](https://s3.br-sao.cloud-object-storage.appdomain.cloud/maratona-static/edit-notebook.png)

# %% [markdown]
# ## Exploração do dataset
#
# O primeiro passo para o desenvolvimento de um bom modelo de Machine Learning é explorar bem os dados que temos para trabalhar. Devemos entender o melhor possível a relevância de cada dado para o valor que queremos predizer. Afinal, a predição do modelo é inteiramente baseada nos dados com que treinou.
#
# Existem muitas bibliotecas em Python que podem ser utilizadas para tratamento e visualização de dados. Nesses exemplos, vamos usar Pandas, Seaborn e Matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Primeiramente, vamos carregar o dataset do desafio neste Notebook. Vamos começar com o principal, `LOANS.csv`. Para isso, podemos usar o ícone de assets, disponível no canto superior direito da tela, e inserir o dataset como um DataFrame Pandas, como na imagem abaixo.
#
# <img width="300px" src="https://s3.br-sao.cloud-object-storage.appdomain.cloud/maratona-static/load-loans.png" />
#
# Repita para todos os datasets que for utilizar.

# %%
# Carregue aqui o dataset
demogra = pd.read_csv("..\data\Demographics.csv")
accounts = pd.read_csv("..\data\Accounts.csv")
loans = pd.read_csv("..\data\loans.csv")

# %% [markdown]
# Renomeie o nome da variável criada com o dataset para `loans`, para ficar de acordo com os códigos abaixo.

# %% [markdown]
# Podemos usar os métodos `.info()` e `.describe()` para obter informações básicas sobre quantidade presente dos dados, tipos e valores deles.

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   3999 non-null   int64
#  1   PAYMENT_TERM         3975 non-null   float64
#  2   INSTALLMENT_PLANS    3978 non-null   object
#  3   INSTALLMENT_PERCENT  3974 non-null   float64
#  4   LOAN_PURPOSE         3979 non-null   object
#  5   LOAN_AMOUNT          3981 non-null   float64
#  6   OTHERS_ON_LOAN       3977 non-null   object
#  7   ALLOW                3999 non-null   int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 250.1+ KB

# %%
loans.describe()
# Out:
#                  ID  PAYMENT_TERM  INSTALLMENT_PERCENT   LOAN_AMOUNT  \
# count  3.999000e+03   3975.000000          3974.000000   3981.000000
# mean   6.603562e+05    653.796981             2.981379   3479.168802
# std    3.728332e+05    338.723239             1.121448   2489.961917
# min    9.800000e+01    120.000000             1.000000    250.000000
# 25%    3.418460e+05    390.000000             2.000000   1330.000000
# 50%    6.670610e+05    651.000000             3.000000   3237.000000
# 75%    9.778745e+05    899.000000             4.000000   5334.000000
# max    1.320082e+06   1984.000000             6.000000  11676.000000
#
#              ALLOW
# count  3999.000000
# mean      0.664166
# std       0.472340
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# A variável destino para este desafio é a `ALLOW`, significando se um empréstimo deverá ser permitido ou não, baseado nas informações dadas. Vamos dar uma olhada em como está a distribuição dessa variável

# %%
risk_plot = sns.countplot(data=loans, x='ALLOW', order=loans['ALLOW'].value_counts().index)
plt.show()

# %% [markdown]
# Sinta-se livre para ver a distribuição de outras colunas do conjunto de dados, utilizar os outros conjuntos de dados, explorar as correlações entre variáveis e outros.

# %%
# Adicione suas explorações

# %%
lo_de = loans.merge(demogra)

# %%
lo_de_ac = lo_de.merge(accounts, on='ID', how='left')
lo_de_ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3936 entries, 0 to 3935
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          3936 non-null   int64
#  1   PAYMENT_TERM                3912 non-null   float64
#  2   INSTALLMENT_PLANS           3915 non-null   object
#  3   INSTALLMENT_PERCENT         3911 non-null   float64
#  4   LOAN_PURPOSE                3917 non-null   object
#  5   LOAN_AMOUNT                 3918 non-null   float64
#  6   OTHERS_ON_LOAN              3914 non-null   object
#  7   ALLOW                       3936 non-null   int64
#  8   SEX                         3920 non-null   object
#  9   AGE                         3918 non-null   float64
#  10  JOB_TYPE                    3910 non-null   float64
#  11  DEPENDENTS                  3915 non-null   float64
#  12  TELEPHONE                   3915 non-null   float64
#  13  FOREIGN_WORKER              3909 non-null   float64
#  14  EMPLOYMENT_DURATION         3923 non-null   float64
#  15  PROPERTY                    3918 non-null   object
#  16  HOUSING                     3912 non-null   object
#  17  CURRENT_RESIDENCE_DURATION  3917 non-null   float64
#  18  CHECKING_BALANCE            2467 non-null   object
#  19  CREDIT_HISTORY              2462 non-null   object
#  20  EXISTING_SAVINGS            2467 non-null   object
#  21  EXISTING_CREDITS_COUNT      2463 non-null   float64
# dtypes: float64(11), int64(2), object(9)
# memory usage: 707.2+ KB

# %%
loans.count()
# Out:
# ID                     3999
# PAYMENT_TERM           3975
# INSTALLMENT_PLANS      3978
# INSTALLMENT_PERCENT    3974
# LOAN_PURPOSE           3979
# LOAN_AMOUNT            3981
# OTHERS_ON_LOAN         3977
# ALLOW                  3999
# dtype: int64

# %% [markdown]
# ## Tratamento dos dados

# %% [markdown]
# Uma vez que exploramos os dados, entendemos a importância de cada coluna e podemos fazer alterações nelas para para obter um melhor resultado. Aqui, vamos fazer apenas um tratamento simples, de remover do dataset as linhas que tiverem faltando algum valor. Não necessariamente essa técnica é a melhor para se utilizar no desafio, é apenas um exemplo de como tratar o dataset.
#
# Para tratamentos mais avançados, como modificação de colunas ou criação de novas colunas, veja mais abaixo no Notebook, em que explicamos como utilizar as `Pipelines`, da biblioteca `sklearn`, para realizar transformações nos dados.

# %%
clean_df = loans.dropna()
clean_df.count()
# Out:
# ID                     3870
# PAYMENT_TERM           3870
# INSTALLMENT_PLANS      3870
# INSTALLMENT_PERCENT    3870
# LOAN_PURPOSE           3870
# LOAN_AMOUNT            3870
# OTHERS_ON_LOAN         3870
# ALLOW                  3870
# dtype: int64

# %% [markdown]
# Podemos observar que agora temos um dataset "limpo", mas perdemos alguns dados por remover as linhas em que pelo menos uma coluna estava faltando.

# %% [markdown]
# Observando a execução do método `.info()` acima, podemos ver que existem três colunas do tipo `object`. O modelo do `scikit-learn` que vamos usar não é capaz de processar uma variável desse tipo. Portanto, para dar seguimento ao experimento, vamos remover essa coluna. Recomendamos que você use alguma técnica para tratamento de variáveis categóricas, como o _one-hot encoding_, em vez de remover a coluna.
#
# Vamos também remover a coluna `ID`, pois sabemos que ela não é uma informação útil para a predição (é apenas um número identificando um cliente).

# %%
object_columns = ['INSTALLMENT_PLANS']
clean_df = clean_df.drop(object_columns, axis=1)
clean_df = clean_df.drop('ID', axis=1)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3870 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PAYMENT_TERM         3870 non-null   float64
#  1   INSTALLMENT_PERCENT  3870 non-null   float64
#  2   LOAN_PURPOSE         3870 non-null   object
#  3   LOAN_AMOUNT          3870 non-null   float64
#  4   OTHERS_ON_LOAN       3870 non-null   object
#  5   ALLOW                3870 non-null   int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 211.6+ KB

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
le = LabelEncoder()
temp = clean_df.copy()
temp['LOAN_PURPOSE_n'] = le.fit_transform(temp['LOAN_PURPOSE'])
temp['OTHERS_ON_LOAN_n'] = le.fit_transform(temp['OTHERS_ON_LOAN'])
temp_n = temp.drop(['LOAN_PURPOSE','OTHERS_ON_LOAN'],axis='columns')

# %%
temp_n
# Out:
#       PAYMENT_TERM  INSTALLMENT_PERCENT  LOAN_AMOUNT  ALLOW  LOAN_PURPOSE_n  \
# 0            713.0                  3.0       3103.0      1               3
# 1            341.0                  1.0        716.0      1               2
# 2            868.0                  4.0       4333.0      1               0
# 3            310.0                  2.0        250.0      1               5
# 4            620.0                  2.0       2454.0      0               3
# ...            ...                  ...          ...    ...             ...
# 3994         450.0                  3.0       3007.0      0               2
# 3995         510.0                  4.0       4191.0      1              10
# 3996         124.0                  1.0        250.0      1               5
# 3997         961.0                  3.0       5172.0      1               1
# 3998        1020.0                  4.0       6063.0      1               5
#
#       OTHERS_ON_LOAN_n
# 0                    2
# 1                    2
# 2                    2
# 3                    2
# 4                    2
# ...                ...
# 3994                 0
# 3995                 1
# 3996                 2
# 3997                 2
# 3998                 2
#
# [3870 rows x 6 columns]

# %% [markdown]
# ## Criação do modelo
#
# Com os dados prontos, podemos selecionar um modelo de Machine Learning para treinar com nossos dados. Nesse exemplo, vamos utilizar um modelo de classificação básico, o de Árvore de Decisão.
#
# Para conseguir avaliar o desempenho do nosso modelo, vamos dividir os dados que temos entre dados de treino e de teste, e assim, após o treinamento, verificar como ele está se saindo com as predições.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Abaixo, separamos os dados que queremos predizer dos dados que utilizamos como informações para a predição.

# %%
features = ['PAYMENT_TERM', 'INSTALLMENT_PERCENT', 'LOAN_AMOUNT','LOAN_PURPOSE_n','OTHERS_ON_LOAN_n']
target = ['ALLOW']

# X = clean_df[features]
# y = clean_df[target]
X = temp_n[features]
y = temp_n[target]

# %%
test_pct = 0.3 # Separaremos 30% dos dados para testes
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_pct)

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Acurácia do modelo (número de predições assertivas sobre número total de testes): {acc}")
# Out:
# Acurácia do modelo (número de predições assertivas sobre número total de testes): 0.6795865633074936

# %%
plt.figure(figsize=(15,7.5))
plot_tree(model, filled=True, rounded=True, class_names=["No HD","Yes HD"], feature_names=X.columns)
# Out:
# [Text(416.4688344396146, 401.3296875, 'LOAN_AMOUNT <= 4351.5\ngini = 0.445\nsamples = 2709\nvalue = [905, 1804]\nclass = Yes HD'),
#  Text(201.0838540442904, 388.5890625, 'PAYMENT_TERM <= 579.5\ngini = 0.307\nsamples = 1724\nvalue = [327, 1397]\nclass = Yes HD'),
#  Text(82.3682191318139, 375.8484375, 'LOAN_AMOUNT <= 906.5\ngini = 0.201\nsamples = 1075\nvalue = [122, 953]\nclass = Yes HD'),
#  Text(38.93937969924812, 363.10781249999997, 'PAYMENT_TERM <= 381.0\ngini = 0.085\nsamples = 470\nvalue = [21, 449]\nclass = Yes HD'),
#  Text(25.172932330827066, 350.3671875, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.059\nsamples = 361\nvalue = [11, 350]\nclass = Yes HD'),
#  Text(19.666353383458645, 337.6265625, 'PAYMENT_TERM <= 122.0\ngini = 0.042\nsamples = 326\nvalue = [7, 319]\nclass = Yes HD'),
#  Text(18.093045112781954, 324.8859375, 'gini = 0.0\nsamples = 86\nvalue = [0, 86]\nclass = Yes HD'),
#  Text(21.239661654135336, 324.8859375, 'PAYMENT_TERM <= 289.5\ngini = 0.057\nsamples = 240\nvalue = [7, 233]\nclass = Yes HD'),
#  Text(19.666353383458645, 312.1453125, 'LOAN_AMOUNT <= 291.0\ngini = 0.077\nsamples = 175\nvalue = [7, 168]\nclass = Yes HD'),
#  Text(18.093045112781954, 299.4046875, 'LOAN_AMOUNT <= 270.0\ngini = 0.095\nsamples = 140\nvalue = [7, 133]\nclass = Yes HD'),
#  Text(16.519736842105264, 286.6640625, 'PAYMENT_TERM <= 274.5\ngini = 0.083\nsamples = 139\nvalue = [6, 133]\nclass = Yes HD'),
#  Text(12.586466165413533, 273.9234375, 'PAYMENT_TERM <= 198.0\ngini = 0.073\nsamples = 132\nvalue = [5, 127]\nclass = Yes HD'),
#  Text(11.013157894736842, 261.18281249999995, 'PAYMENT_TERM <= 183.0\ngini = 0.103\nsamples = 92\nvalue = [5, 87]\nclass = Yes HD'),
#  Text(7.866541353383458, 248.4421875, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.086\nsamples = 89\nvalue = [4, 85]\nclass = Yes HD'),
#  Text(6.293233082706767, 235.7015625, 'LOAN_PURPOSE_n <= 2.5\ngini = 0.159\nsamples = 46\nvalue = [4, 42]\nclass = Yes HD'),
#  Text(4.719924812030075, 222.9609375, 'PAYMENT_TERM <= 137.0\ngini = 0.213\nsamples = 33\nvalue = [4, 29]\nclass = Yes HD'),
#  Text(3.1466165413533833, 210.2203125, 'OTHERS_ON_LOAN_n <= 1.0\ngini = 0.245\nsamples = 28\nvalue = [4, 24]\nclass = Yes HD'),
#  Text(1.5733082706766917, 197.47968749999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(4.719924812030075, 197.47968749999998, 'LOAN_PURPOSE_n <= 1.0\ngini = 0.269\nsamples = 25\nvalue = [4, 21]\nclass = Yes HD'),
#  Text(3.1466165413533833, 184.7390625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(6.293233082706767, 184.7390625, 'gini = 0.278\nsamples = 24\nvalue = [4, 20]\nclass = Yes HD'),
#  Text(6.293233082706767, 210.2203125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(7.866541353383458, 222.9609375, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Yes HD'),
#  Text(9.43984962406015, 235.7015625, 'gini = 0.0\nsamples = 43\nvalue = [0, 43]\nclass = Yes HD'),
#  Text(14.159774436090224, 248.4421875, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(12.586466165413533, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(15.733082706766917, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(14.159774436090224, 261.18281249999995, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]\nclass = Yes HD'),
#  Text(20.45300751879699, 273.9234375, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Yes HD'),
#  Text(18.8796992481203, 261.18281249999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(22.026315789473685, 261.18281249999995, 'LOAN_PURPOSE_n <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Yes HD'),
#  Text(20.45300751879699, 248.4421875, 'OTHERS_ON_LOAN_n <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(18.8796992481203, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(22.026315789473685, 235.7015625, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(23.599624060150376, 248.4421875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(19.666353383458645, 286.6640625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(21.239661654135336, 299.4046875, 'gini = 0.0\nsamples = 35\nvalue = [0, 35]\nclass = Yes HD'),
#  Text(22.81296992481203, 312.1453125, 'gini = 0.0\nsamples = 65\nvalue = [0, 65]\nclass = Yes HD'),
#  Text(30.679511278195488, 337.6265625, 'LOAN_PURPOSE_n <= 2.5\ngini = 0.202\nsamples = 35\nvalue = [4, 31]\nclass = Yes HD'),
#  Text(27.532894736842103, 324.8859375, 'PAYMENT_TERM <= 274.0\ngini = 0.375\nsamples = 12\nvalue = [3, 9]\nclass = Yes HD'),
#  Text(25.959586466165412, 312.1453125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(29.106203007518797, 312.1453125, 'LOAN_AMOUNT <= 572.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = No HD'),
#  Text(27.532894736842103, 299.4046875, 'PAYMENT_TERM <= 305.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = No HD'),
#  Text(25.959586466165412, 286.6640625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(29.106203007518797, 286.6640625, 'PAYMENT_TERM <= 325.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(27.532894736842103, 273.9234375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(30.679511278195488, 273.9234375, 'PAYMENT_TERM <= 356.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(29.106203007518797, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(32.25281954887218, 261.18281249999995, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(30.679511278195488, 299.4046875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(33.82612781954887, 324.8859375, 'LOAN_AMOUNT <= 804.0\ngini = 0.083\nsamples = 23\nvalue = [1, 22]\nclass = Yes HD'),
#  Text(32.25281954887218, 312.1453125, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = Yes HD'),
#  Text(35.399436090225564, 312.1453125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(52.70582706766917, 350.3671875, 'LOAN_AMOUNT <= 271.5\ngini = 0.167\nsamples = 109\nvalue = [10, 99]\nclass = Yes HD'),
#  Text(47.19924812030075, 337.6265625, 'LOAN_PURPOSE_n <= 8.5\ngini = 0.236\nsamples = 66\nvalue = [9, 57]\nclass = Yes HD'),
#  Text(44.05263157894737, 324.8859375, 'PAYMENT_TERM <= 442.0\ngini = 0.2\nsamples = 62\nvalue = [7, 55]\nclass = Yes HD'),
#  Text(42.47932330827067, 312.1453125, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]\nclass = Yes HD'),
#  Text(45.62593984962406, 312.1453125, 'PAYMENT_TERM <= 518.5\ngini = 0.263\nsamples = 45\nvalue = [7, 38]\nclass = Yes HD'),
#  Text(42.47932330827067, 299.4046875, 'LOAN_PURPOSE_n <= 6.0\ngini = 0.355\nsamples = 26\nvalue = [6, 20]\nclass = Yes HD'),
#  Text(40.90601503759398, 286.6640625, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]\nclass = Yes HD'),
#  Text(39.33270676691729, 273.9234375, 'PAYMENT_TERM <= 472.5\ngini = 0.415\nsamples = 17\nvalue = [5, 12]\nclass = Yes HD'),
#  Text(35.399436090225564, 261.18281249999995, 'LOAN_PURPOSE_n <= 1.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = Yes HD'),
#  Text(33.82612781954887, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(36.972744360902254, 248.4421875, 'LOAN_PURPOSE_n <= 4.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Yes HD'),
#  Text(33.82612781954887, 235.7015625, 'PAYMENT_TERM <= 457.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(32.25281954887218, 222.9609375, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(35.399436090225564, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(40.119360902255636, 235.7015625, 'PAYMENT_TERM <= 457.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(38.546052631578945, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(41.69266917293233, 222.9609375, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(43.26597744360902, 261.18281249999995, 'LOAN_PURPOSE_n <= 1.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Yes HD'),
#  Text(41.69266917293233, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(44.839285714285715, 248.4421875, 'PAYMENT_TERM <= 503.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Yes HD'),
#  Text(43.26597744360902, 235.7015625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(46.412593984962406, 235.7015625, 'LOAN_PURPOSE_n <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(44.839285714285715, 222.9609375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(47.9859022556391, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(42.47932330827067, 273.9234375, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(44.05263157894737, 286.6640625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(48.77255639097744, 299.4046875, 'PAYMENT_TERM <= 564.0\ngini = 0.1\nsamples = 19\nvalue = [1, 18]\nclass = Yes HD'),
#  Text(47.19924812030075, 286.6640625, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = Yes HD'),
#  Text(50.34586466165413, 286.6640625, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(48.77255639097744, 273.9234375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(51.919172932330824, 273.9234375, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(50.34586466165413, 324.8859375, 'PAYMENT_TERM <= 426.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(48.77255639097744, 312.1453125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(51.919172932330824, 312.1453125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(58.212406015037594, 337.6265625, 'PAYMENT_TERM <= 396.5\ngini = 0.045\nsamples = 43\nvalue = [1, 42]\nclass = Yes HD'),
#  Text(56.639097744360896, 324.8859375, 'LOAN_AMOUNT <= 728.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Yes HD'),
#  Text(55.065789473684205, 312.1453125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(58.212406015037594, 312.1453125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(59.785714285714285, 324.8859375, 'gini = 0.0\nsamples = 38\nvalue = [0, 38]\nclass = Yes HD'),
#  Text(125.7970585643797, 363.10781249999997, 'LOAN_AMOUNT <= 915.0\ngini = 0.278\nsamples = 605\nvalue = [101, 504]\nclass = Yes HD'),
#  Text(124.223750293703, 350.3671875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(127.37036683505639, 350.3671875, 'OTHERS_ON_LOAN_n <= 1.5\ngini = 0.274\nsamples = 603\nvalue = [99, 504]\nclass = Yes HD'),
#  Text(71.58552631578947, 337.6265625, 'LOAN_AMOUNT <= 3795.0\ngini = 0.406\nsamples = 60\nvalue = [17, 43]\nclass = Yes HD'),
#  Text(70.01221804511277, 324.8859375, 'LOAN_PURPOSE_n <= 2.5\ngini = 0.383\nsamples = 58\nvalue = [15, 43]\nclass = Yes HD'),
#  Text(61.359022556390975, 312.1453125, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.492\nsamples = 16\nvalue = [7, 9]\nclass = Yes HD'),
#  Text(59.785714285714285, 299.4046875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(62.932330827067666, 299.4046875, 'LOAN_AMOUNT <= 2985.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]\nclass = Yes HD'),
#  Text(61.359022556390975, 286.6640625, 'LOAN_AMOUNT <= 1890.0\ngini = 0.496\nsamples = 11\nvalue = [5, 6]\nclass = Yes HD'),
#  Text(56.639097744360896, 273.9234375, 'PAYMENT_TERM <= 435.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Yes HD'),
#  Text(55.065789473684205, 261.18281249999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(58.212406015037594, 261.18281249999995, 'PAYMENT_TERM <= 457.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(56.639097744360896, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(59.785714285714285, 248.4421875, 'LOAN_AMOUNT <= 1731.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(58.212406015037594, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(61.359022556390975, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(66.07894736842105, 273.9234375, 'PAYMENT_TERM <= 360.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(64.50563909774436, 261.18281249999995, 'PAYMENT_TERM <= 274.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(62.932330827067666, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(66.07894736842105, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(67.65225563909775, 261.18281249999995, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(64.50563909774436, 286.6640625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(78.66541353383458, 312.1453125, 'OTHERS_ON_LOAN_n <= 0.5\ngini = 0.308\nsamples = 42\nvalue = [8, 34]\nclass = Yes HD'),
#  Text(77.09210526315789, 299.4046875, 'LOAN_PURPOSE_n <= 6.0\ngini = 0.283\nsamples = 41\nvalue = [7, 34]\nclass = Yes HD'),
#  Text(70.79887218045113, 286.6640625, 'PAYMENT_TERM <= 427.0\ngini = 0.153\nsamples = 24\nvalue = [2, 22]\nclass = Yes HD'),
#  Text(69.22556390977444, 273.9234375, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Yes HD'),
#  Text(72.37218045112782, 273.9234375, 'PAYMENT_TERM <= 442.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Yes HD'),
#  Text(70.79887218045113, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(73.94548872180451, 261.18281249999995, 'PAYMENT_TERM <= 487.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Yes HD'),
#  Text(72.37218045112782, 248.4421875, 'LOAN_PURPOSE_n <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(70.79887218045113, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(73.94548872180451, 235.7015625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(75.5187969924812, 248.4421875, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(83.38533834586465, 286.6640625, 'LOAN_PURPOSE_n <= 7.5\ngini = 0.415\nsamples = 17\nvalue = [5, 12]\nclass = Yes HD'),
#  Text(78.66541353383458, 273.9234375, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = No HD'),
#  Text(77.09210526315789, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(80.23872180451127, 261.18281249999995, 'PAYMENT_TERM <= 503.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Yes HD'),
#  Text(78.66541353383458, 248.4421875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(81.81203007518796, 248.4421875, 'PAYMENT_TERM <= 549.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(80.23872180451127, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(83.38533834586465, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(88.10526315789474, 273.9234375, 'PAYMENT_TERM <= 396.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]\nclass = Yes HD'),
#  Text(86.53195488721803, 261.18281249999995, 'PAYMENT_TERM <= 182.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(84.95864661654134, 248.4421875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(88.10526315789474, 248.4421875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(89.67857142857143, 261.18281249999995, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(80.23872180451127, 299.4046875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(73.15883458646616, 324.8859375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(183.1552073543233, 337.6265625, 'LOAN_AMOUNT <= 4156.0\ngini = 0.256\nsamples = 543\nvalue = [82, 461]\nclass = Yes HD'),
#  Text(151.55383576127818, 324.8859375, 'PAYMENT_TERM <= 427.0\ngini = 0.246\nsamples = 521\nvalue = [75, 446]\nclass = Yes HD'),
#  Text(116.71980733082707, 312.1453125, 'LOAN_PURPOSE_n <= 3.5\ngini = 0.201\nsamples = 309\nvalue = [35, 274]\nclass = Yes HD'),
#  Text(104.4283364661654, 299.4046875, 'LOAN_AMOUNT <= 1098.0\ngini = 0.163\nsamples = 190\nvalue = [17, 173]\nclass = Yes HD'),
#  Text(95.9718045112782, 286.6640625, 'LOAN_AMOUNT <= 1079.0\ngini = 0.363\nsamples = 21\nvalue = [5, 16]\nclass = Yes HD'),
#  Text(94.3984962406015, 273.9234375, 'LOAN_AMOUNT <= 962.0\ngini = 0.266\nsamples = 19\nvalue = [3, 16]\nclass = Yes HD'),
#  Text(92.82518796992481, 261.18281249999995, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Yes HD'),
#  Text(95.9718045112782, 261.18281249999995, 'LOAN_AMOUNT <= 989.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Yes HD'),
#  Text(94.3984962406015, 248.4421875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(97.54511278195488, 248.4421875, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(97.54511278195488, 273.9234375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(112.88486842105263, 286.6640625, 'LOAN_AMOUNT <= 3921.0\ngini = 0.132\nsamples = 169\nvalue = [12, 157]\nclass = Yes HD'),
#  Text(106.98496240601503, 273.9234375, 'PAYMENT_TERM <= 396.5\ngini = 0.107\nsamples = 159\nvalue = [9, 150]\nclass = Yes HD'),
#  Text(102.26503759398496, 261.18281249999995, 'LOAN_AMOUNT <= 2685.0\ngini = 0.07\nsamples = 137\nvalue = [5, 132]\nclass = Yes HD'),
#  Text(100.69172932330827, 248.4421875, 'LOAN_AMOUNT <= 2661.5\ngini = 0.105\nsamples = 90\nvalue = [5, 85]\nclass = Yes HD'),
#  Text(99.11842105263158, 235.7015625, 'LOAN_AMOUNT <= 2249.5\ngini = 0.086\nsamples = 89\nvalue = [4, 85]\nclass = Yes HD'),
#  Text(93.61184210526315, 222.9609375, 'PAYMENT_TERM <= 335.5\ngini = 0.056\nsamples = 70\nvalue = [2, 68]\nclass = Yes HD'),
#  Text(90.46522556390977, 210.2203125, 'PAYMENT_TERM <= 137.0\ngini = 0.033\nsamples = 59\nvalue = [1, 58]\nclass = Yes HD'),
#  Text(88.89191729323308, 197.47968749999998, 'LOAN_AMOUNT <= 1412.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]\nclass = Yes HD'),
#  Text(87.31860902255639, 184.7390625, 'LOAN_AMOUNT <= 1353.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Yes HD'),
#  Text(85.7453007518797, 171.9984375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(88.89191729323308, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(90.46522556390977, 184.7390625, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Yes HD'),
#  Text(92.03853383458646, 197.47968749999998, 'gini = 0.0\nsamples = 42\nvalue = [0, 42]\nclass = Yes HD'),
#  Text(96.75845864661653, 210.2203125, 'LOAN_PURPOSE_n <= 2.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Yes HD'),
#  Text(95.18515037593984, 197.47968749999998, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(98.33176691729322, 197.47968749999998, 'LOAN_AMOUNT <= 1805.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(96.75845864661653, 184.7390625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(99.90507518796991, 184.7390625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(104.625, 222.9609375, 'LOAN_AMOUNT <= 2281.5\ngini = 0.188\nsamples = 19\nvalue = [2, 17]\nclass = Yes HD'),
#  Text(103.05169172932331, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(106.19830827067669, 210.2203125, 'PAYMENT_TERM <= 259.0\ngini = 0.105\nsamples = 18\nvalue = [1, 17]\nclass = Yes HD'),
#  Text(104.625, 197.47968749999998, 'LOAN_AMOUNT <= 2386.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Yes HD'),
#  Text(103.05169172932331, 184.7390625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(106.19830827067669, 184.7390625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(107.77161654135338, 197.47968749999998, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Yes HD'),
#  Text(102.26503759398496, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(103.83834586466165, 248.4421875, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]\nclass = Yes HD'),
#  Text(111.7048872180451, 261.18281249999995, 'LOAN_AMOUNT <= 1480.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]\nclass = Yes HD'),
#  Text(107.77161654135338, 248.4421875, 'LOAN_AMOUNT <= 1398.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Yes HD'),
#  Text(106.19830827067669, 235.7015625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(109.34492481203007, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(115.63815789473684, 248.4421875, 'LOAN_AMOUNT <= 3351.0\ngini = 0.208\nsamples = 17\nvalue = [2, 15]\nclass = Yes HD'),
#  Text(112.49154135338345, 235.7015625, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = Yes HD'),
#  Text(110.91823308270676, 222.9609375, 'LOAN_AMOUNT <= 2095.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(109.34492481203007, 210.2203125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(112.49154135338345, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(114.06484962406014, 222.9609375, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Yes HD'),
#  Text(118.78477443609022, 235.7015625, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(117.21146616541353, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(120.35808270676691, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(118.78477443609022, 273.9234375, 'LOAN_AMOUNT <= 3996.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Yes HD'),
#  Text(117.21146616541353, 261.18281249999995, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(120.35808270676691, 261.18281249999995, 'PAYMENT_TERM <= 245.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Yes HD'),
#  Text(118.78477443609022, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(121.9313909774436, 248.4421875, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(129.01127819548873, 299.4046875, 'LOAN_AMOUNT <= 1327.5\ngini = 0.257\nsamples = 119\nvalue = [18, 101]\nclass = Yes HD'),
#  Text(127.43796992481202, 286.6640625, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]\nclass = Yes HD'),
#  Text(130.5845864661654, 286.6640625, 'LOAN_AMOUNT <= 1364.5\ngini = 0.298\nsamples = 99\nvalue = [18, 81]\nclass = Yes HD'),
#  Text(129.01127819548873, 273.9234375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(132.1578947368421, 273.9234375, 'LOAN_PURPOSE_n <= 4.5\ngini = 0.275\nsamples = 97\nvalue = [16, 81]\nclass = Yes HD'),
#  Text(126.65131578947368, 261.18281249999995, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(125.07800751879698, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(128.22462406015038, 248.4421875, 'LOAN_AMOUNT <= 1714.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(126.65131578947368, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(129.79793233082705, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(137.66447368421052, 261.18281249999995, 'LOAN_AMOUNT <= 2031.0\ngini = 0.256\nsamples = 93\nvalue = [14, 79]\nclass = Yes HD'),
#  Text(134.51785714285714, 248.4421875, 'LOAN_AMOUNT <= 1561.0\ngini = 0.062\nsamples = 31\nvalue = [1, 30]\nclass = Yes HD'),
#  Text(132.94454887218043, 235.7015625, 'LOAN_AMOUNT <= 1540.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]\nclass = Yes HD'),
#  Text(131.37124060150376, 222.9609375, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Yes HD'),
#  Text(134.51785714285714, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(136.09116541353382, 235.7015625, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]\nclass = Yes HD'),
#  Text(140.8110902255639, 248.4421875, 'LOAN_AMOUNT <= 2060.5\ngini = 0.331\nsamples = 62\nvalue = [13, 49]\nclass = Yes HD'),
#  Text(139.23778195488723, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(142.3843984962406, 235.7015625, 'LOAN_AMOUNT <= 3613.5\ngini = 0.316\nsamples = 61\nvalue = [12, 49]\nclass = Yes HD'),
#  Text(140.8110902255639, 222.9609375, 'LOAN_AMOUNT <= 3319.5\ngini = 0.36\nsamples = 51\nvalue = [12, 39]\nclass = Yes HD'),
#  Text(134.51785714285714, 210.2203125, 'PAYMENT_TERM <= 320.0\ngini = 0.31\nsamples = 47\nvalue = [9, 38]\nclass = Yes HD'),
#  Text(129.79793233082705, 197.47968749999998, 'LOAN_AMOUNT <= 2628.0\ngini = 0.426\nsamples = 26\nvalue = [8, 18]\nclass = Yes HD'),
#  Text(125.07800751879698, 184.7390625, 'PAYMENT_TERM <= 170.5\ngini = 0.5\nsamples = 14\nvalue = [7, 7]\nclass = No HD'),
#  Text(120.35808270676691, 171.9984375, 'LOAN_PURPOSE_n <= 8.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Yes HD'),
#  Text(118.78477443609022, 159.2578125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(121.9313909774436, 159.2578125, 'LOAN_AMOUNT <= 2237.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(120.35808270676691, 146.51718749999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(123.50469924812029, 146.51718749999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(129.79793233082705, 171.9984375, 'LOAN_AMOUNT <= 2243.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = No HD'),
#  Text(128.22462406015038, 159.2578125, 'LOAN_AMOUNT <= 2207.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Yes HD'),
#  Text(126.65131578947368, 146.51718749999998, 'LOAN_AMOUNT <= 2171.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(125.07800751879698, 133.7765625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(128.22462406015038, 133.7765625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(129.79793233082705, 146.51718749999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(131.37124060150376, 159.2578125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(134.51785714285714, 184.7390625, 'PAYMENT_TERM <= 289.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Yes HD'),
#  Text(132.94454887218043, 171.9984375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Yes HD'),
#  Text(136.09116541353382, 171.9984375, 'LOAN_AMOUNT <= 3213.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(134.51785714285714, 159.2578125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(137.66447368421052, 159.2578125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(139.23778195488723, 197.47968749999998, 'PAYMENT_TERM <= 411.5\ngini = 0.091\nsamples = 21\nvalue = [1, 20]\nclass = Yes HD'),
#  Text(137.66447368421052, 184.7390625, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]\nclass = Yes HD'),
#  Text(140.8110902255639, 184.7390625, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(139.23778195488723, 171.9984375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(142.3843984962406, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(147.10432330827066, 210.2203125, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(145.531015037594, 197.47968749999998, 'LOAN_AMOUNT <= 3387.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(143.95770676691728, 184.7390625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(147.10432330827066, 184.7390625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(148.67763157894737, 197.47968749999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(143.95770676691728, 222.9609375, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Yes HD'),
#  Text(186.3878641917293, 312.1453125, 'LOAN_PURPOSE_n <= 7.5\ngini = 0.306\nsamples = 212\nvalue = [40, 172]\nclass = Yes HD'),
#  Text(164.312382518797, 299.4046875, 'LOAN_AMOUNT <= 1056.5\ngini = 0.33\nsamples = 182\nvalue = [38, 144]\nclass = Yes HD'),
#  Text(162.7390742481203, 286.6640625, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Yes HD'),
#  Text(165.88569078947367, 286.6640625, 'LOAN_AMOUNT <= 1150.0\ngini = 0.346\nsamples = 171\nvalue = [38, 133]\nclass = Yes HD'),
#  Text(151.0375939849624, 273.9234375, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = No HD'),
#  Text(149.4642857142857, 261.18281249999995, 'LOAN_PURPOSE_n <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(147.89097744360902, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(151.0375939849624, 248.4421875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(152.6109022556391, 261.18281249999995, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(180.73378759398494, 273.9234375, 'PAYMENT_TERM <= 549.0\ngini = 0.333\nsamples = 166\nvalue = [35, 131]\nclass = Yes HD'),
#  Text(164.41071428571428, 261.18281249999995, 'LOAN_AMOUNT <= 1727.5\ngini = 0.302\nsamples = 135\nvalue = [25, 110]\nclass = Yes HD'),
#  Text(154.18421052631578, 248.4421875, 'LOAN_PURPOSE_n <= 1.0\ngini = 0.145\nsamples = 38\nvalue = [3, 35]\nclass = Yes HD'),
#  Text(150.25093984962405, 235.7015625, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(148.67763157894737, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(151.82424812030075, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(158.11748120300751, 235.7015625, 'PAYMENT_TERM <= 533.5\ngini = 0.105\nsamples = 36\nvalue = [2, 34]\nclass = Yes HD'),
#  Text(154.97086466165413, 222.9609375, 'LOAN_PURPOSE_n <= 2.5\ngini = 0.057\nsamples = 34\nvalue = [1, 33]\nclass = Yes HD'),
#  Text(153.39755639097743, 210.2203125, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = Yes HD'),
#  Text(151.82424812030075, 197.47968749999998, 'LOAN_AMOUNT <= 1391.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Yes HD'),
#  Text(150.25093984962405, 184.7390625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(153.39755639097743, 184.7390625, 'LOAN_AMOUNT <= 1558.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(151.82424812030075, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(154.97086466165413, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(154.97086466165413, 197.47968749999998, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(156.5441729323308, 210.2203125, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]\nclass = Yes HD'),
#  Text(161.2640977443609, 222.9609375, 'LOAN_AMOUNT <= 1475.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(159.6907894736842, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(162.83740601503757, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(174.63721804511277, 248.4421875, 'PAYMENT_TERM <= 518.5\ngini = 0.351\nsamples = 97\nvalue = [22, 75]\nclass = Yes HD'),
#  Text(170.70394736842104, 235.7015625, 'LOAN_AMOUNT <= 1867.0\ngini = 0.39\nsamples = 79\nvalue = [21, 58]\nclass = Yes HD'),
#  Text(167.55733082706766, 222.9609375, 'LOAN_AMOUNT <= 1764.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = No HD'),
#  Text(165.98402255639098, 210.2203125, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(164.41071428571428, 197.47968749999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(167.55733082706766, 197.47968749999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(169.13063909774436, 210.2203125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(173.85056390977442, 222.9609375, 'LOAN_AMOUNT <= 4013.5\ngini = 0.346\nsamples = 72\nvalue = [16, 56]\nclass = Yes HD'),
#  Text(172.27725563909775, 210.2203125, 'LOAN_AMOUNT <= 3991.0\ngini = 0.364\nsamples = 67\nvalue = [16, 51]\nclass = Yes HD'),
#  Text(170.70394736842104, 197.47968749999998, 'LOAN_AMOUNT <= 1943.0\ngini = 0.351\nsamples = 66\nvalue = [15, 51]\nclass = Yes HD'),
#  Text(169.13063909774436, 184.7390625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(172.27725563909775, 184.7390625, 'LOAN_AMOUNT <= 1947.0\ngini = 0.367\nsamples = 62\nvalue = [15, 47]\nclass = Yes HD'),
#  Text(170.70394736842104, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(173.85056390977442, 171.9984375, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.354\nsamples = 61\nvalue = [14, 47]\nclass = Yes HD'),
#  Text(172.27725563909775, 159.2578125, 'PAYMENT_TERM <= 503.0\ngini = 0.375\nsamples = 56\nvalue = [14, 42]\nclass = Yes HD'),
#  Text(165.98402255639098, 146.51718749999998, 'LOAN_PURPOSE_n <= 1.0\ngini = 0.405\nsamples = 46\nvalue = [13, 33]\nclass = Yes HD'),
#  Text(164.41071428571428, 133.7765625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(167.55733082706766, 133.7765625, 'PAYMENT_TERM <= 472.5\ngini = 0.391\nsamples = 45\nvalue = [12, 33]\nclass = Yes HD'),
#  Text(159.6907894736842, 121.03593749999999, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]\nclass = Yes HD'),
#  Text(158.11748120300751, 108.29531250000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(161.2640977443609, 108.29531250000002, 'LOAN_AMOUNT <= 3476.5\ngini = 0.278\nsamples = 24\nvalue = [4, 20]\nclass = Yes HD'),
#  Text(159.6907894736842, 95.5546875, 'LOAN_AMOUNT <= 2995.5\ngini = 0.346\nsamples = 18\nvalue = [4, 14]\nclass = Yes HD'),
#  Text(158.11748120300751, 82.81406249999998, 'LOAN_PURPOSE_n <= 6.0\ngini = 0.219\nsamples = 16\nvalue = [2, 14]\nclass = Yes HD'),
#  Text(154.97086466165413, 70.07343750000001, 'LOAN_AMOUNT <= 2622.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = Yes HD'),
#  Text(153.39755639097743, 57.33281249999999, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Yes HD'),
#  Text(156.5441729323308, 57.33281249999999, 'PAYMENT_TERM <= 457.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(154.97086466165413, 44.59218750000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(158.11748120300751, 44.59218750000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(161.2640977443609, 70.07343750000001, 'PAYMENT_TERM <= 442.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(159.6907894736842, 57.33281249999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(162.83740601503757, 57.33281249999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(161.2640977443609, 82.81406249999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(162.83740601503757, 95.5546875, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Yes HD'),
#  Text(175.42387218045113, 121.03593749999999, 'LOAN_AMOUNT <= 3617.0\ngini = 0.455\nsamples = 20\nvalue = [7, 13]\nclass = Yes HD'),
#  Text(173.85056390977442, 108.29531250000002, 'LOAN_AMOUNT <= 3041.0\ngini = 0.401\nsamples = 18\nvalue = [5, 13]\nclass = Yes HD'),
#  Text(172.27725563909775, 95.5546875, 'LOAN_AMOUNT <= 3008.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]\nclass = Yes HD'),
#  Text(170.70394736842104, 82.81406249999998, 'LOAN_AMOUNT <= 2901.0\ngini = 0.426\nsamples = 13\nvalue = [4, 9]\nclass = Yes HD'),
#  Text(169.13063909774436, 70.07343750000001, 'LOAN_AMOUNT <= 2598.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]\nclass = Yes HD'),
#  Text(165.98402255639098, 57.33281249999999, 'PAYMENT_TERM <= 488.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Yes HD'),
#  Text(164.41071428571428, 44.59218750000002, 'LOAN_PURPOSE_n <= 4.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Yes HD'),
#  Text(162.83740601503757, 31.8515625, 'LOAN_AMOUNT <= 2330.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(161.2640977443609, 19.110937499999977, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(164.41071428571428, 19.110937499999977, 'LOAN_AMOUNT <= 2388.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(162.83740601503757, 6.370312500000011, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(165.98402255639098, 6.370312500000011, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(165.98402255639098, 31.8515625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(167.55733082706766, 44.59218750000002, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(172.27725563909775, 57.33281249999999, 'LOAN_PURPOSE_n <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(170.70394736842104, 44.59218750000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(173.85056390977442, 44.59218750000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(172.27725563909775, 70.07343750000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(173.85056390977442, 82.81406249999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(175.42387218045113, 95.5546875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(176.9971804511278, 108.29531250000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(178.5704887218045, 146.51718749999998, 'LOAN_PURPOSE_n <= 4.0\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = Yes HD'),
#  Text(176.9971804511278, 133.7765625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Yes HD'),
#  Text(180.14379699248119, 133.7765625, 'LOAN_AMOUNT <= 2950.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(178.5704887218045, 121.03593749999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(181.7171052631579, 121.03593749999999, 'LOAN_AMOUNT <= 3561.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(180.14379699248119, 108.29531250000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(183.29041353383457, 108.29531250000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(175.42387218045113, 159.2578125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(173.85056390977442, 197.47968749999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(175.42387218045113, 210.2203125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(178.5704887218045, 235.7015625, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]\nclass = Yes HD'),
#  Text(176.9971804511278, 222.9609375, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]\nclass = Yes HD'),
#  Text(180.14379699248119, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(197.05686090225564, 261.18281249999995, 'LOAN_AMOUNT <= 3251.5\ngini = 0.437\nsamples = 31\nvalue = [10, 21]\nclass = Yes HD'),
#  Text(191.9436090225564, 248.4421875, 'LOAN_AMOUNT <= 2747.0\ngini = 0.483\nsamples = 22\nvalue = [9, 13]\nclass = Yes HD'),
#  Text(186.43703007518795, 235.7015625, 'PAYMENT_TERM <= 564.0\ngini = 0.444\nsamples = 18\nvalue = [6, 12]\nclass = Yes HD'),
#  Text(183.29041353383457, 222.9609375, 'LOAN_AMOUNT <= 1335.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = No HD'),
#  Text(181.7171052631579, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(184.86372180451127, 210.2203125, 'LOAN_AMOUNT <= 1823.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(183.29041353383457, 197.47968749999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(186.43703007518795, 197.47968749999998, 'LOAN_PURPOSE_n <= 6.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(184.86372180451127, 184.7390625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(188.01033834586465, 184.7390625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(189.58364661654136, 222.9609375, 'LOAN_PURPOSE_n <= 0.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = Yes HD'),
#  Text(188.01033834586465, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(191.15695488721803, 210.2203125, 'INSTALLMENT_PERCENT <= 1.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Yes HD'),
#  Text(189.58364661654136, 197.47968749999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(192.73026315789474, 197.47968749999998, 'LOAN_AMOUNT <= 1260.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Yes HD'),
#  Text(191.15695488721803, 184.7390625, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(189.58364661654136, 171.9984375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(192.73026315789474, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(194.30357142857142, 184.7390625, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(197.4501879699248, 235.7015625, 'PAYMENT_TERM <= 564.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(195.87687969924812, 222.9609375, 'LOAN_AMOUNT <= 3005.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(194.30357142857142, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(197.4501879699248, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(199.0234962406015, 222.9609375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(202.17011278195488, 248.4421875, 'LOAN_AMOUNT <= 4002.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Yes HD'),
#  Text(200.59680451127818, 235.7015625, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(203.74342105263156, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(208.46334586466165, 299.4046875, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.124\nsamples = 30\nvalue = [2, 28]\nclass = Yes HD'),
#  Text(206.89003759398494, 286.6640625, 'PAYMENT_TERM <= 488.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Yes HD'),
#  Text(205.31672932330827, 273.9234375, 'LOAN_AMOUNT <= 2318.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(203.74342105263156, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(206.89003759398494, 261.18281249999995, 'LOAN_AMOUNT <= 3120.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(205.31672932330827, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(208.46334586466165, 248.4421875, 'LOAN_AMOUNT <= 3855.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(206.89003759398494, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(210.03665413533832, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(208.46334586466165, 273.9234375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(210.03665413533832, 286.6640625, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = Yes HD'),
#  Text(214.7565789473684, 324.8859375, 'PAYMENT_TERM <= 457.5\ngini = 0.434\nsamples = 22\nvalue = [7, 15]\nclass = Yes HD'),
#  Text(213.1832706766917, 312.1453125, 'PAYMENT_TERM <= 259.0\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = No HD'),
#  Text(211.60996240601503, 299.4046875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(214.7565789473684, 299.4046875, 'LOAN_PURPOSE_n <= 9.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = No HD'),
#  Text(213.1832706766917, 286.6640625, 'PAYMENT_TERM <= 411.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = No HD'),
#  Text(211.60996240601503, 273.9234375, 'LOAN_AMOUNT <= 4227.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = No HD'),
#  Text(210.03665413533832, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(213.1832706766917, 261.18281249999995, 'LOAN_AMOUNT <= 4302.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = No HD'),
#  Text(211.60996240601503, 248.4421875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(214.7565789473684, 248.4421875, 'LOAN_AMOUNT <= 4314.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(213.1832706766917, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(216.32988721804512, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(214.7565789473684, 273.9234375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(216.32988721804512, 286.6640625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(216.32988721804512, 312.1453125, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Yes HD'),
#  Text(319.7994889567669, 375.8484375, 'OTHERS_ON_LOAN_n <= 1.5\ngini = 0.432\nsamples = 649\nvalue = [205, 444]\nclass = Yes HD'),
#  Text(233.04628759398494, 363.10781249999997, 'PAYMENT_TERM <= 1067.5\ngini = 0.484\nsamples = 56\nvalue = [33, 23]\nclass = No HD'),
#  Text(231.47297932330827, 350.3671875, 'LOAN_PURPOSE_n <= 0.5\ngini = 0.495\nsamples = 51\nvalue = [28, 23]\nclass = No HD'),
#  Text(222.62312030075188, 337.6265625, 'LOAN_AMOUNT <= 3132.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = No HD'),
#  Text(221.04981203007517, 324.8859375, 'LOAN_AMOUNT <= 2449.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(219.4765037593985, 312.1453125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(222.62312030075188, 312.1453125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(224.19642857142856, 324.8859375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(240.32283834586465, 337.6265625, 'LOAN_PURPOSE_n <= 6.5\ngini = 0.5\nsamples = 44\nvalue = [22, 22]\nclass = No HD'),
#  Text(232.84962406015038, 324.8859375, 'PAYMENT_TERM <= 701.5\ngini = 0.48\nsamples = 25\nvalue = [10, 15]\nclass = Yes HD'),
#  Text(225.76973684210526, 312.1453125, 'LOAN_AMOUNT <= 1236.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = No HD'),
#  Text(224.19642857142856, 299.4046875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(227.34304511278194, 299.4046875, 'LOAN_PURPOSE_n <= 2.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Yes HD'),
#  Text(225.76973684210526, 286.6640625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(228.91635338345864, 286.6640625, 'LOAN_AMOUNT <= 2299.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(227.34304511278194, 273.9234375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(230.48966165413532, 273.9234375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(239.9295112781955, 312.1453125, 'LOAN_AMOUNT <= 4198.0\ngini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = Yes HD'),
#  Text(238.3562030075188, 299.4046875, 'PAYMENT_TERM <= 976.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]\nclass = Yes HD'),
#  Text(236.78289473684208, 286.6640625, 'LOAN_AMOUNT <= 2264.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Yes HD'),
#  Text(233.6362781954887, 273.9234375, 'INSTALLMENT_PERCENT <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(232.06296992481202, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(235.2095864661654, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(239.9295112781955, 273.9234375, 'PAYMENT_TERM <= 884.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Yes HD'),
#  Text(238.3562030075188, 261.18281249999995, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Yes HD'),
#  Text(241.50281954887217, 261.18281249999995, 'PAYMENT_TERM <= 899.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(239.9295112781955, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
# ...
#  Text(498.7387218045113, 222.9609375, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(497.16541353383457, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(500.3120300751879, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(501.8853383458646, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(500.3120300751879, 261.18281249999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(500.3120300751879, 286.6640625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(508.1785714285714, 337.6265625, 'LOAN_AMOUNT <= 5669.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]\nclass = No HD'),
#  Text(505.03195488721803, 324.8859375, 'PAYMENT_TERM <= 960.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = No HD'),
#  Text(503.45864661654133, 312.1453125, 'LOAN_PURPOSE_n <= 7.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(501.8853383458646, 299.4046875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(505.03195488721803, 299.4046875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(506.60526315789474, 312.1453125, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = No HD'),
#  Text(511.3251879699248, 324.8859375, 'PAYMENT_TERM <= 1133.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(509.7518796992481, 312.1453125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(512.8984962406015, 312.1453125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(512.8984962406015, 350.3671875, 'PAYMENT_TERM <= 300.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Yes HD'),
#  Text(511.3251879699248, 337.6265625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(514.4718045112782, 337.6265625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Yes HD'),
#  Text(536.4151528724154, 363.10781249999997, 'PAYMENT_TERM <= 615.0\ngini = 0.219\nsamples = 248\nvalue = [217, 31]\nclass = No HD'),
#  Text(534.8418446017387, 350.3671875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(537.9884611430921, 350.3671875, 'LOAN_AMOUNT <= 6210.5\ngini = 0.208\nsamples = 246\nvalue = [217, 29]\nclass = No HD'),
#  Text(536.4151528724154, 337.6265625, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = No HD'),
#  Text(539.5617694137687, 337.6265625, 'LOAN_AMOUNT <= 6219.5\ngini = 0.23\nsamples = 219\nvalue = [190, 29]\nclass = No HD'),
#  Text(537.9884611430921, 324.8859375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(541.1350776844455, 324.8859375, 'LOAN_AMOUNT <= 6309.5\ngini = 0.224\nsamples = 218\nvalue = [190, 28]\nclass = No HD'),
#  Text(534.420861724624, 312.1453125, 'LOAN_AMOUNT <= 6257.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = No HD'),
#  Text(532.8475534539474, 299.4046875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(535.9941699953007, 299.4046875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(547.8492936442669, 312.1453125, 'LOAN_AMOUNT <= 8874.0\ngini = 0.215\nsamples = 212\nvalue = [186, 26]\nclass = No HD'),
#  Text(539.1407865366541, 299.4046875, 'LOAN_AMOUNT <= 8144.5\ngini = 0.19\nsamples = 169\nvalue = [151, 18]\nclass = No HD'),
#  Text(533.1302572838346, 286.6640625, 'LOAN_AMOUNT <= 8119.5\ngini = 0.224\nsamples = 132\nvalue = [115, 17]\nclass = No HD'),
#  Text(531.5569490131579, 273.9234375, 'PAYMENT_TERM <= 1585.5\ngini = 0.214\nsamples = 131\nvalue = [115, 16]\nclass = No HD'),
#  Text(524.2558153195489, 261.18281249999995, 'LOAN_AMOUNT <= 7977.5\ngini = 0.199\nsamples = 125\nvalue = [111, 14]\nclass = No HD'),
#  Text(514.3734727443609, 248.4421875, 'PAYMENT_TERM <= 854.0\ngini = 0.18\nsamples = 120\nvalue = [108, 12]\nclass = No HD'),
#  Text(506.60526315789474, 235.7015625, 'LOAN_AMOUNT <= 6559.0\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = No HD'),
#  Text(505.03195488721803, 222.9609375, 'LOAN_AMOUNT <= 6453.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(503.45864661654133, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(506.60526315789474, 210.2203125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(508.1785714285714, 222.9609375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No HD'),
#  Text(522.141682330827, 235.7015625, 'LOAN_PURPOSE_n <= 8.5\ngini = 0.153\nsamples = 108\nvalue = [99, 9]\nclass = No HD'),
#  Text(516.438439849624, 222.9609375, 'LOAN_AMOUNT <= 7692.0\ngini = 0.131\nsamples = 99\nvalue = [92, 7]\nclass = No HD'),
#  Text(509.7518796992481, 210.2203125, 'PAYMENT_TERM <= 1280.5\ngini = 0.092\nsamples = 83\nvalue = [79, 4]\nclass = No HD'),
#  Text(505.81860902255636, 197.47968749999998, 'LOAN_AMOUNT <= 6687.5\ngini = 0.034\nsamples = 58\nvalue = [57, 1]\nclass = No HD'),
#  Text(504.24530075187965, 184.7390625, 'LOAN_AMOUNT <= 6657.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = No HD'),
#  Text(502.671992481203, 171.9984375, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = No HD'),
#  Text(505.81860902255636, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(507.39191729323306, 184.7390625, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]\nclass = No HD'),
#  Text(513.6851503759398, 197.47968749999998, 'PAYMENT_TERM <= 1296.0\ngini = 0.211\nsamples = 25\nvalue = [22, 3]\nclass = No HD'),
#  Text(510.5385338345864, 184.7390625, 'INSTALLMENT_PERCENT <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(508.96522556390977, 171.9984375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(512.1118421052631, 171.9984375, 'LOAN_PURPOSE_n <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(510.5385338345864, 159.2578125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(513.6851503759398, 159.2578125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(516.8317669172932, 184.7390625, 'PAYMENT_TERM <= 1509.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = No HD'),
#  Text(515.2584586466165, 171.9984375, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = No HD'),
#  Text(518.4050751879699, 171.9984375, 'LOAN_PURPOSE_n <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(516.8317669172932, 159.2578125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(519.9783834586466, 159.2578125, 'INSTALLMENT_PERCENT <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(518.4050751879699, 146.51718749999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(521.5516917293232, 146.51718749999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(523.125, 210.2203125, 'LOAN_AMOUNT <= 7837.0\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = No HD'),
#  Text(521.5516917293232, 197.47968749999998, 'PAYMENT_TERM <= 991.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = No HD'),
#  Text(519.9783834586466, 184.7390625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(523.125, 184.7390625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(524.6983082706766, 197.47968749999998, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = No HD'),
#  Text(527.8449248120301, 222.9609375, 'LOAN_AMOUNT <= 6987.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = No HD'),
#  Text(526.2716165413534, 210.2203125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(529.4182330827067, 210.2203125, 'INSTALLMENT_PERCENT <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No HD'),
#  Text(527.8449248120301, 197.47968749999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(530.9915413533835, 197.47968749999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(534.1381578947368, 248.4421875, 'LOAN_AMOUNT <= 8054.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = No HD'),
#  Text(532.5648496240601, 235.7015625, 'LOAN_AMOUNT <= 7992.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(530.9915413533835, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(534.1381578947368, 222.9609375, 'LOAN_PURPOSE_n <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(532.5648496240601, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(535.7114661654135, 210.2203125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(535.7114661654135, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(538.8580827067669, 261.18281249999995, 'PAYMENT_TERM <= 1650.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = No HD'),
#  Text(537.2847744360902, 248.4421875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(540.4313909774436, 248.4421875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No HD'),
#  Text(534.7035655545112, 273.9234375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(545.1513157894736, 286.6640625, 'LOAN_PURPOSE_n <= 1.5\ngini = 0.053\nsamples = 37\nvalue = [36, 1]\nclass = No HD'),
#  Text(543.578007518797, 273.9234375, 'LOAN_AMOUNT <= 8455.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = No HD'),
#  Text(542.0046992481202, 261.18281249999995, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No HD'),
#  Text(545.1513157894736, 261.18281249999995, 'PAYMENT_TERM <= 1110.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = No HD'),
#  Text(543.578007518797, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(546.7246240601504, 248.4421875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No HD'),
#  Text(546.7246240601504, 273.9234375, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = No HD'),
#  Text(556.5578007518797, 299.4046875, 'LOAN_AMOUNT <= 9028.0\ngini = 0.303\nsamples = 43\nvalue = [35, 8]\nclass = No HD'),
#  Text(551.4445488721805, 286.6640625, 'LOAN_PURPOSE_n <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(549.8712406015037, 273.9234375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(553.0178571428571, 273.9234375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(561.671052631579, 286.6640625, 'LOAN_PURPOSE_n <= 3.5\ngini = 0.224\nsamples = 39\nvalue = [34, 5]\nclass = No HD'),
#  Text(556.1644736842105, 273.9234375, 'LOAN_AMOUNT <= 9864.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = No HD'),
#  Text(553.0178571428571, 261.18281249999995, 'LOAN_AMOUNT <= 9470.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Yes HD'),
#  Text(551.4445488721805, 248.4421875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(554.5911654135338, 248.4421875, 'PAYMENT_TERM <= 898.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes HD'),
#  Text(553.0178571428571, 235.7015625, 'INSTALLMENT_PERCENT <= 5.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(551.4445488721805, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(554.5911654135338, 222.9609375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(556.1644736842105, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(559.3110902255639, 261.18281249999995, 'PAYMENT_TERM <= 1140.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = No HD'),
#  Text(557.7377819548872, 248.4421875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(560.8843984962406, 248.4421875, 'PAYMENT_TERM <= 1275.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(559.3110902255639, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(562.4577067669172, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(567.1776315789474, 273.9234375, 'LOAN_PURPOSE_n <= 7.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]\nclass = No HD'),
#  Text(565.6043233082706, 261.18281249999995, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = No HD'),
#  Text(568.750939849624, 261.18281249999995, 'PAYMENT_TERM <= 1190.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = No HD'),
#  Text(567.1776315789474, 248.4421875, 'LOAN_AMOUNT <= 9673.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(565.6043233082706, 235.7015625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(568.750939849624, 235.7015625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(570.3242481203007, 248.4421875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No HD'),
#  Text(743.0824075569783, 375.8484375, 'PAYMENT_TERM <= 899.5\ngini = 0.499\nsamples = 667\nvalue = [316, 351]\nclass = Yes HD'),
#  Text(680.3114022850094, 363.10781249999997, 'INSTALLMENT_PERCENT <= 4.5\ngini = 0.486\nsamples = 417\nvalue = [173, 244]\nclass = Yes HD'),
#  Text(623.3312162241541, 350.3671875, 'LOAN_AMOUNT <= 4488.0\ngini = 0.477\nsamples = 387\nvalue = [152, 235]\nclass = Yes HD'),
#  Text(567.1776315789474, 337.6265625, 'LOAN_AMOUNT <= 4395.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]\nclass = No HD'),
#  Text(563.2443609022556, 324.8859375, 'LOAN_PURPOSE_n <= 1.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = No HD'),
#  Text(561.671052631579, 312.1453125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(564.8176691729323, 312.1453125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No HD'),
#  Text(571.1109022556391, 324.8859375, 'LOAN_AMOUNT <= 4426.5\ngini = 0.49\nsamples = 21\nvalue = [12, 9]\nclass = No HD'),
#  Text(567.9642857142857, 312.1453125, 'LOAN_PURPOSE_n <= 3.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Yes HD'),
#  Text(566.390977443609, 299.4046875, 'PAYMENT_TERM <= 747.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = No HD'),
#  Text(564.8176691729323, 286.6640625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(567.9642857142857, 286.6640625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(569.5375939849624, 299.4046875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Yes HD'),
#  Text(574.2575187969925, 312.1453125, 'INSTALLMENT_PERCENT <= 3.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = No HD'),
#  Text(572.6842105263157, 299.4046875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No HD'),
#  Text(575.8308270676691, 299.4046875, 'PAYMENT_TERM <= 793.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Yes HD'),
#  Text(574.2575187969925, 286.6640625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes HD'),
#  Text(577.4041353383458, 286.6640625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No HD'),
#  Text(679.4848008693609, 337.6265625, 'LOAN_AMOUNT <= 7778.5\ngini = 0.466\nsamples = 357\nvalue = [132, 225]\nclass = Yes HD'),
#  Text(632.691171287594, 324.8859375, 'PAYMENT_TERM <= 625.0\ngini = 0.458\nsamples = 344\nvalue = [122, 222]\nclass = Yes HD'),
#  Text(594.5138627819549, 312.1453125, 'LOAN_AMOUNT <= 4798.5\ngini = 0.391\nsamples = 109\nvalue = [29, 80]\nclass = Yes HD'),
#  Text(584.484022556391, 299.4046875, 'LOAN_PURPOSE_n <= 1.0\ngini = 0.204\nsamples = 26\nvalue = [3, 23]\nclass = Yes HD'),
#  Text(580.5507518796992, 286.6640625, 'LOAN_AMOUNT <= 4593.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = No HD'),
#  Text(578.9774436090225, 273.9234375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes HD'),
#  Text(582.124060150376, 273.9234375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(588.4172932330827, 286.6640625, 'LOAN_AMOUNT <= 4535.0\ngini = 0.153\nsamples = 24\nvalue = [2, 22]\nclass = Yes HD'),
#  Text(585.2706766917292, 273.9234375, 'LOAN_AMOUNT <= 4513.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Yes HD'),
#  Text(583.6973684210526, 261.18281249999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes HD'),
#  Text(586.843984962406, 261.18281249999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No HD'),
#  Text(591.5639097744361, 273.9234375, 'INSTALLMENT_PERCENT <= 2.5\ngini = 0.091\nsamples = 21\nvalue = [1, 20]\nclass = Yes HD'),
#  ...]

# %%
plot_confusion_matrix(model, X_test, y_test, display_labels=["No Allow", "Allow"])
# Out:
# C:\Users\a362014\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
path = model.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas
ccp_alphas = ccp_alphas[:-1]

model_dts = []

for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    model.fit(X_train, y_train)
    model_dts.append(model)

# %%
train_scores = [model.score(X_train, y_train) for model in model_dts]
test_scores = [model.score(X_test, y_test) for model in model_dts]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker='o', label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test", drawstyle="steps-post")
ax.legend()
plt.show()

# %%
model = DecisionTreeClassifier(random_state=42, ccp_alpha=0.0025)
scores = cross_val_score(model, X_train, y_train, cv=5)
df1 = pd.DataFrame(data={'tree':range(5), 'accuracy':scores})
df1.plot(x='tree', y='accuracy', marker='o', linestyle='--')
# Out:
# <AxesSubplot:xlabel='tree'>

# %%
alpha_loop_values = []

for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    scores = cross_val_score(model, X_train, y_train, cv=5)
    alpha_loop_values.append([ccp_alpha, np.mean(scores),np.std(scores)])

alpha_results = pd.DataFrame(alpha_loop_values, columns=['alpha','mean_accuracy','std'])
plt.figure(figsize=(15,7.5))
alpha_results.plot(x='alpha', y='mean_accuracy', yerr='std', marker='o', linestyle='--')
# Out:
# <AxesSubplot:xlabel='alpha'>

# %%
# alpha_results[(alpha_results['alpha'] > 0.001) & (alpha_results['alpha'] < 0.0034)]
temp2 = alpha_results[(alpha_results.mean_accuracy == alpha_results.mean_accuracy.max())]
temp3 = temp2[(temp2.alpha == temp2.alpha.max())]['alpha']

# %%
ideal_ccp_alpha = float(temp3)
ideal_ccp_alpha
# Out:
# 0.00299117883093878

# %%
test_pct = 0.3 # Separaremos 30% dos dados para testes
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_pct)

model_pruned = DecisionTreeClassifier(random_state=42, ccp_alpha=ideal_ccp_alpha)
model_pruned.fit(X_train,y_train)

y_pred = model_pruned.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Acurácia do modelo (número de predições assertivas sobre número total de testes): {acc}")
# Out:
# Acurácia do modelo (número de predições assertivas sobre número total de testes): 0.7579672695951766

# %%
ConfusionMatrixDisplay.from_estimator(model_pruned, X_test, y_test, display_labels=["No Allow", "Allow"])

# %%
plt.figure(figsize=(15,7.5))
plot_tree(model_pruned, filled=True, rounded=True, class_names=["No Allow","Yes Allow"], feature_names=X.columns)
# Out:
# [Text(342.40909090909093, 356.7375, 'PAYMENT_TERM <= 671.0\ngini = 0.449\nsamples = 2709\nvalue = [923, 1786]\nclass = Yes Allow'),
#  Text(152.1818181818182, 254.8125, 'LOAN_AMOUNT <= 970.5\ngini = 0.274\nsamples = 1442\nvalue = [236, 1206]\nclass = Yes Allow'),
#  Text(76.0909090909091, 152.8875, 'gini = 0.114\nsamples = 545\nvalue = [33, 512]\nclass = Yes Allow'),
#  Text(228.27272727272728, 152.8875, 'gini = 0.35\nsamples = 897\nvalue = [203, 694]\nclass = Yes Allow'),
#  Text(532.6363636363636, 254.8125, 'OTHERS_ON_LOAN_n <= 1.5\ngini = 0.496\nsamples = 1267\nvalue = [687, 580]\nclass = No Allow'),
#  Text(380.4545454545455, 152.8875, 'LOAN_AMOUNT <= 5077.0\ngini = 0.31\nsamples = 334\nvalue = [270, 64]\nclass = No Allow'),
#  Text(304.3636363636364, 50.96249999999998, 'gini = 0.497\nsamples = 63\nvalue = [34, 29]\nclass = No Allow'),
#  Text(456.54545454545456, 50.96249999999998, 'gini = 0.225\nsamples = 271\nvalue = [236, 35]\nclass = No Allow'),
#  Text(684.8181818181819, 152.8875, 'LOAN_AMOUNT <= 4522.5\ngini = 0.494\nsamples = 933\nvalue = [417, 516]\nclass = Yes Allow'),
#  Text(608.7272727272727, 50.96249999999998, 'gini = 0.459\nsamples = 423\nvalue = [151, 272]\nclass = Yes Allow'),
#  Text(760.909090909091, 50.96249999999998, 'gini = 0.499\nsamples = 510\nvalue = [266, 244]\nclass = No Allow')]

# %% [markdown]
# Apesar de estarmos utilizando somente algumas variáveis do dataset carregado, o desafio espera um modelo que aceite todas as variáveis dos conjuntos de dados disponíveis. Portanto, vamos utilizar um transformador para transformar os dados de entrada, removendo as colunas que não queremos, antes enviá-los ao nosso modelo. Dessa forma, criaremos uma `Pipeline`, que utiliza o transformador como entrada, e o nosso modelo em seguida.
#
# Fica como tarefa para você unir os outros conjuntos de dados disponíveis e utilizá-los também para predições no modelo, em vez de remover as colunas.

# %% [markdown]
# ## Sobre Pipelines
#
# Uma `Pipeline`, da biblioteca `scikit-learn`, consiste em uma série de passos onde realizamos transformações em dados. As transformações são definidas por classes que devem ter sempre **dois métodos**:
#
# - **fit**: Um método que recebe dados de treinamento, e retorna a própria instância da classe. Ele é aplicado quando se vai treinar utilizar uma Pipeline para treinar um modelo.
# - **transform**: Um método que recebe como entrada um conjunto de dados e deve retornar um outro conjunto de dados, transformado. Ele é aplicado em cada etapa da Pipeline, recebendo os dados do passo anterior e transformando-os.
#
# Veja abaixo uma representação gráfica do funcionamento de uma Pipeline:

# %% [markdown]
# ![](https://s3.br-sao.cloud-object-storage.appdomain.cloud/maratona-static/pipeline.png)

# %% [markdown]
# Nesse Notebook, vamos criar uma Pipeline muito similar ao exemplo acima, com dois estágios:
#
# - **drop_columns**: Remove as colunas indesejadas do conjunto de dados de entrada.
# - **classification**: Alimenta um modelo de classificação com os dados obtidos no estágio **drop_columns**, podendo ser tanto para treinamento quanto para obter uma predição.

# %% [markdown]
# ## Criação de Pipelines no scikit-learn
#
# Para criar um modelo capaz de fazer transformações nos dados de entrada, vamos criar uma `Pipeline` do `scikit-learn` e aplicar nossas transformações dentro dos estágios dela.
#
# Abaixo, definimos um transformador exemplo, que irá remover as colunas passadas como parâmetro em sua inicialização:

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline


# Um transformador para remover colunas indesejadas
class DropColumns(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        # Primeiro realizamos a cópia do DataFrame 'X' de entrada
        data = X.copy()
        # Retornamos um novo dataframe sem as colunas indesejadas
        return data.drop(labels=self.columns, axis='columns')

# %% [markdown]
# Tanto o método `fit` quanto o `transform` devem obrigatoriamente ser definidos, mesmo se não forem fazer nada de diferente, como no caso do `fit` acima.
#
# Da mesma forma, você pode criar outros transformadores, para outros propósitos, sempre herdando das classes `BaseEstimator` e `TransformerMixin`. Você pode utilizar um transformador para, por exemplo, criar novas colunas, editar tipos de dados de colunas existentes, entre outros.
#
# Agora, vamos criar uma Pipeline para utilização do nosso modelo, aceitando todas as colunas esperadas pelo desafio e removendo as que não queremos usar.

# %%
challenge_columns = ['ID', 'CHECKING_BALANCE', 'PAYMENT_TERM', 'CREDIT_HISTORY',
       'LOAN_PURPOSE', 'LOAN_AMOUNT', 'EXISTING_SAVINGS',
       'EMPLOYMENT_DURATION', 'INSTALLMENT_PERCENT', 'SEX', 'OTHERS_ON_LOAN',
       'CURRENT_RESIDENCE_DURATION', 'PROPERTY', 'AGE', 'INSTALLMENT_PLANS',
       'HOUSING', 'EXISTING_CREDITS_COUNT', 'JOB_TYPE', 'DEPENDENTS',
       'TELEPHONE', 'FOREIGN_WORKER', 'ALLOW']

unwanted_columns = list((set(challenge_columns) - set(target)) - set(features)) # Remover todas as colunas que não são features do nosso modelo

# %%
# Criando uma instância do transformador, passando como parâmetro as colunas que não queremos
drop_columns = DropColumns(unwanted_columns)


# Criando a Pipeline, adicionando o nosso transformador seguido de um modelo de árvore de decisão
skl_pipeline = Pipeline(steps=[('drop_columns', drop_columns), ('classification', model)])

# %% [markdown]
# Pronto! Essa pipeline agora está pronta para receber todas as variáveis do desafio, apesar de o modelo só usar algumas.

# %% [markdown]
# ## Deploy do modelo para o Watson Machine Learning (WML)
#
# Agora temos o modelo pronto para publicação, queremos deixá-lo online para que o sistema da Maratona possa testá-lo :)
#
# Para isso, vamos utilizar a biblioteca `IBM Watson Machine Learning`, que permite realizar o encapsulamento de modelos de Machine Learning em APIs REST.

# %%
# Instalar a biblioteca do WML
# !pip install -U ibm-watson-machine-learning

# %%
from ibm_watson_machine_learning import APIClient

# %% [markdown]
# Caso ainda não tiver criado, crie um serviço de Machine Learning aqui: https://cloud.ibm.com/catalog/services/machine-learning.
#
# Insira suas credenciais para o serviço na célula abaixo.
#
# Em `location`, insira o ID da região onde se encontra o seu serviço WML instanciado, de acordo com as possibilidades abaixo:
#
# - Dallas - `us-south`
# - London - `eu-gb`
# - Frankfurt - `eu-de`
# - Tokyo - `jp-tok`
#
# Para a API key, você deve gerá-la aqui: https://cloud.ibm.com/iam/apikeys. Não compartilhe-a com ninguém! Uma API key dá acesso à sua conta IBM Cloud.

# %%
api_key = 'INSIRA SUA API KEY AQUI'
location = 'us-south' # Caso o WML estiver em uma região diferente, altere

wml_credentials = {
    "apikey": api_key,
    "url": 'https://' + location + '.ml.cloud.ibm.com'
}

client = APIClient(wml_credentials)

# %% [markdown]
# Crie um espaço para salvar o seu modelo. Você pode criá-lo aqui: https://dataplatform.cloud.ibm.com/ml-runtime/spaces?context=cpdaas
#
# Quando criar o seu espaço, **associe a instância do seu serviço WML ao espaço!** Sem associar, você não conseguirá efetuar o deploy.

# %%
# Listar espaços criados na sua instância de WML
client.spaces.list(limit=10)

# %% [markdown]
# Copie o ID do seu espaço criado para o desafio e cole-o abaixo para utilizá-lo. Você deverá ver a mensagem 'SUCCESS' se o espaço estiver corretamente configurado.

# %%
space_id = 'cole aqui'
client.set.default_space(space_id)

# %% [markdown]
# ## Utilização da Pipeline dentro do Watson Machine Learning (WML)
#
# Para utilizar uma Pipeline no WML com transformadores customizados, são necessários alguns passos adicionais:
#
# 1. Criar um pacote no Python contendo o transformador customizado;
# 2. Carregar esse pacote com o transformador em um repositório no WML;
# 3. Criar uma especificação de software, com esse pacote customizado, que vai ser utilizada como tempo de execução do modelo no WML.
#
# Como exemplo, vamos utilizar um pacote já pronto, disponível aqui: https://github.com/vnderlev/watson-sklearn-transforms. Para configurar o pacote Python, são necessários alguns outros arquivos, mas a lógica do transformador criado se encontra [neste arquivo](https://github.com/vnderlev/watson-sklearn-transforms/blob/master/my_custom_sklearn_transforms/sklearn_transformers.py). No caso, esse é o mesmo transformador que definimos aqui, ele vai excluir do conjunto de dados as colunas passadas como parâmetro na sua inicialização.
#
# Abaixo, vamos baixar esse pacote do GitHub e instalá-lo no Python.

# %%
# !rm -rf watson-sklearn-transforms # Remover a pasta caso já exista
# !git clone https://github.com/vnderlev/watson-sklearn-transforms # Clonar o repositório com o pacote
# !zip -r drop-columns.zip watson-sklearn-transforms # Zipar o pacote
# !pip install drop-columns.zip # Instalar o pacote zipado

# %% [markdown]
# Vamos agora recriar nossa Pipeline utilizando esse pacote instalado.

# %%
from my_custom_sklearn_transforms.sklearn_transformers import DropColumns

drop_columns = DropColumns(unwanted_columns)

pipeline = Pipeline(steps=[('drop_columns', drop_columns), ('classification', model)])

# %% [markdown]
# Vamos agora subir o transformador customizado que baixamos para o WML.

# %%
# Metadados para o pacote customizado
meta_prop_pkg_extn = {
    client.package_extensions.ConfigurationMetaNames.NAME: "Drop_Columns",
    client.package_extensions.ConfigurationMetaNames.DESCRIPTION: "Extensão para remover colunas",
    client.package_extensions.ConfigurationMetaNames.TYPE: "pip_zip"
}

# Subir o pacote
pkg_extn_details = client.package_extensions.store(meta_props=meta_prop_pkg_extn, file_path="drop-columns.zip")

# Salvar as informações sobre o pacote
pkg_extn_uid = client.package_extensions.get_uid(pkg_extn_details)
pkg_extn_url = client.package_extensions.get_href(pkg_extn_details)

# %% [markdown]
# Vamos agora criar uma especificação de software com o nosso pacote customizado, para que o WML possa utilizar. Caso estiver utilizando um software diferente de `Python 3.8` ou biblioteca diferente de `scikit-learn`, você pode dar uma olhada na lista de especificações de software suportadas pelo WML: https://dataplatform.cloud.ibm.com/docs/content/wsj/wmls/wmls-deploy-python-types.html?context=analytics&audience=wdp

# %%
base_sw_spec_uid = client.software_specifications.get_uid_by_name("default_py3.8")

# Caso queira utilizar um software diferente de Python 3.8 como base, dê uma olhada nos disponíveis com a linha abaixo
# client.software_specifications.list(limit=100)

# %%
# Metadados da nova especificação de software
meta_prop_sw_spec = {
    client.software_specifications.ConfigurationMetaNames.NAME: "sw_spec_drop_columns",
    client.software_specifications.ConfigurationMetaNames.DESCRIPTION: "Software specification utilizando DropColumns",
    client.software_specifications.ConfigurationMetaNames.BASE_SOFTWARE_SPECIFICATION: {"guid": base_sw_spec_uid}
}

# Criando a nova especificação de software e obtendo seu ID
sw_spec_details = client.software_specifications.store(meta_props=meta_prop_sw_spec)
sw_spec_uid = client.software_specifications.get_uid(sw_spec_details)

# Adicionando o pacote customizado à nova especificação
client.software_specifications.add_package_extension(sw_spec_uid, pkg_extn_uid)

# %% [markdown]
# Finalmente, vamos publicar a pipeline utilizando a especificação de software customizada que criamos.

# %%
# Metadados do modelo
model_props = {
    client.repository.ModelMetaNames.NAME: "Modelo com Pipeline customizada",
    client.repository.ModelMetaNames.TYPE: 'scikit-learn_0.23',
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: sw_spec_uid
}

# Publicando a Pipeline como um modelo
published_model = client.repository.store_model(model=pipeline, meta_props=model_props)
published_model_uid = client.repository.get_model_uid(published_model)
client.repository.get_details(published_model_uid)

# %% [markdown]
# Seu modelo agora está salvo. Vamos agora deixá-lo disponível online, para que possamos testá-lo:

# %%
# Metadados para publicação do modelo
metadata = {
    client.deployments.ConfigurationMetaNames.NAME: "Publicação do modelo customizado",
    client.deployments.ConfigurationMetaNames.ONLINE: {}
}

# Publicar
created_deployment = client.deployments.create(published_model_uid, meta_props=metadata)

# %% [markdown]
# ## Parabéns!
#
# Seu modelo está agora publicado. Quando estiver pronto para submeter o desafio, você pode acessar https://maratona.dev/challenges/1, e utilizar as credenciais abaixo para realizar a submissão. Lembre-se de revisar todas as instruções no [README](https://github.com/maratonadev/desafio-1-2021) antes de submeter!

# %%
deployment_uid = client.deployments.get_uid(created_deployment)

print(f"Credenciais para envio (não compartilhe esses dados com ninguém!)\n\nAPI key: {api_key}\nDeployment ID: {deployment_uid}")
